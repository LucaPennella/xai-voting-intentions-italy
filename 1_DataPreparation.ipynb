# %%
import pandas as pd
import numpy as np
from sklearn.model_selection import train_test_split, RandomizedSearchCV, cross_val_score, cross_val_predict,cross_validate
from sklearn.metrics import accuracy_score, precision_score, recall_score, f1_score, fbeta_score, make_scorer, confusion_matrix, precision_recall_curve
from sklearn.model_selection import GridSearchCV
from sklearn.ensemble import RandomForestClassifier
from sklearn.preprocessing import LabelEncoder
from sklearn.metrics import confusion_matrix, classification_report
import seaborn as sns
import matplotlib.pyplot as plt
from sklearn.feature_selection import RFE
import lightgbm as lgb
from xgboost import XGBClassifier
from sklearn.tree import DecisionTreeClassifier

from skopt import BayesSearchCV
from skopt.space import Real, Integer, Categorical
import optuna

# %%
filepath = r"C:\Users\lucap\OneDrive\Desktop\PhD\Racheal\Dati\dataset_clean.csv"
df = pd.read_csv(filepath, sep = ";" )

# %%
df.shape
# Out:
# (4504, 161)

# %%
diz_aliases_int_voto = {"Partito Democratico-PD":'Sx/CSx',
                "Partito Democratico":'Sx/CSx',
                "Lega con Salvini":'Dx/CDx',
                "Lega Nord":'Dx/CDx',
                "Lega":'Dx/CDx',
                "Forza Italia":'Dx/CDx',
                "Fratelli d'Italia":"Dx/CDx",
                'MoVimento 5 Stelle':'M5S',
                'Movimento 5 stelle':'M5S',
                'voterei  scheda bianca / annullerei la scheda':'astensione/bianca/nulla',
                'voterei scheda bianca / scheda nulla':'astensione/bianca/nulla',
                "+Europa":'Sx/CSx',
                "piu' Europa con Emma Bonino": "Sx/CSx",
                'Sinistra italiana (SEL + altri)':'Sx/CSx',
                'Potere al Popolo':'Sx/CSx',
                'Rifondazione Comunista':'Sx/CSx',
                "Fratelli d'Italia-Alleanza Nazionale&nbsp;":"Dx/CDx",
                'La Sinistra':'Sx/CSx',
                'Verdi':'Sx/CSx',
                'non andrei a votare':'astensione/bianca/nulla',
                'sono indeciso' : 'indecisi',
                'Liberi e Uguali' : 'Sx/CSx',
                'Italia dei Valori' : 'Sx/CSx',
                'Scelta Civica&nbsp;' : 'Sx/CSx',
                'Italia Unica di Corrado Passera' : 'Sx/CSx',
                "Noi con l'Italia UDC&nbsp;" : 'Dx/CDx',
                "altro partito di area di governo (SVP, Centro Democratico....)" : 'Altro partito',
                "Nuovo Centro Destra con UDC e PPI" : 'Dx/CDx'
                }

# %%
df['m_p_int_voto'] = df['m_p_int_voto'].replace(diz_aliases_int_voto)
df['m_p_int_voto'].value_counts()
# Out:
# m_p_int_voto
# Sx/CSx                       1348
# Dx/CDx                       1102
# M5S                           869
# indecisi                      695
# astensione/bianca/nulla       274
# preferisco non rispondere     150
# Altro partito                  66
# Name: count, dtype: int64

# %%
df = df[~df['m_p_int_voto'].isin(['Altro partito', 'preferisco non rispondere', 'indecisi','astensione/bianca/nulla' ])]

# %%
df['m_p_int_voto'].value_counts()
# Out:
# m_p_int_voto
# Sx/CSx    1348
# Dx/CDx    1102
# M5S        869
# Name: count, dtype: int64

# %%
diz_aliases_ac = {"del tutto d'accordo":2,
            "del tutto<BR>d'accordo":2,
		     "d'accordo":1,
		     "ne' d'accordo ne' in disaccordo (NON STIMOLARE)":0,
             "ne d'accordo ne' in disaccordo":0,
             "ne' d'accordo ne' in disaccordo":0,
             "preferisco non rispondere":0,
             "preferisco<BR>non<BR> rispondere":0,
            "non saprei":0,
             "in disaccordo":-1,
             'del tutto in disaccordo':-2,
             "del tutto disaccordo":-2,
             "del tutto<BR>in disaccordo":-2,
             
            
}

nomi_var = df.columns.tolist()
for var in nomi_var:
    if '_ac_' in var:
        df[var] = df[var].replace(diz_aliases_ac)
        
        
diz_aliases_op = {"molto":2,
            "poco":-1,
            "pocao":-1,
		     "abbastanza":1,
		     "non saprei":0,
            "nessuno":-2,
            "per niente":-2}

nomi_var = df.columns.tolist()
for var in nomi_var:
    if 'op' in var:
        df[var] = df[var].replace(diz_aliases_op)
        

diz_aliases_trend = {"in trend":1,
                 "slight in trend":1,
                 "slight off trend":0,
                 "off trend":0,
                 'non classificati':0}
 
nomi_var = df.columns.tolist()
for var in nomi_var:
    if 'TREND' in var:
        df[var] = df[var].replace(diz_aliases_trend)
        
        
diz_aliases_scol = {"elementare/privo di titolo":1,
                 "media inferiore":1,
                 "diploma di maturita` (5 anni)":2,
                 "superiori in corso":2,
                 'diploma di istituto professionale (3 anni)':2,
                 'universita` in corso/nessuna laurea conseguita':4,
                 'laurea triennale di I livello':4,
                 'diploma universitario/laurea breve':4,
                 'laurea specialistica di II livello o laurea 4-5 anni':4,
                 'master/scuola di specializzazione post laurea':4,
                 'dottorato di ricerca':4
                 }
 
df['m_p_scolarita'] = df['m_p_scolarita'].replace(diz_aliases_scol)



diz_aliases_geo = {'meno di 5.000':1,
                 'da 5.001 a 10.000':1,
                 'da 10.001 a 30.000':2,
                 'da 30.001 a 100.000':2,
                 'da 100.001 a 250.000':3,
                 'piu` di 250.001':3
                 }
 
df['m_p_r_ampiezza6'] = df['m_p_r_ampiezza6'].replace(diz_aliases_geo)

diz_aliases_eco = {
                 "mi sento povero e non arrivo mai a fine mese":-1,
                 "avverto difficolta'":-1,
                 "arrivo a fine mese con molte difficolta'":-1,
                 "con tranquillita'":1,
                 'agiatamente':1
                 }
 
df['m_op_come_reddito_consenteDiVivere'] = df['m_op_come_reddito_consenteDiVivere'].replace(diz_aliases_eco)


df = pd.get_dummies(df, columns=['m_op_preferenza_lavorativa'], prefix='prf_lav',dtype=int)

#df = pd.get_dummies(df, columns=['m_p_zona_5istat'], prefix='zona')
df = pd.get_dummies(df, columns=['m_istat_reg'], prefix='reg',dtype=int)

diz_aliases_quot = {
                 0:0,
                 'preferisco non rispondere':0,
                 "si alcune volte alla settimana":1,
                 "si ogni giorno":1
                 }
 
df['m_p_lettura_quotidiani'] = df['m_p_lettura_quotidiani'].replace(diz_aliases_quot)

diz_aliases_freq_y = {'mai':0,
                     "piu' raramente":0,
                 "alcune volte l'anno":1,
                  "piu' volte alla settimana":2,
                 'mensile':1,
                 'settimanale':2}
 
nomi_var = df.columns.tolist()
for var in nomi_var:
    if 'm_p_' in var:
        df[var] = df[var].replace(diz_aliases_freq_y)
        
        
diz_aliases_freq = {'non saprei':0,
                     "non ascolto la radio":0,
                 "da piu' di un'ora fino a due ore":1,
                  "da piu' di tre ore fino a quattro ore":2,
                 'oltre quattro':2,
                 "da piu' di due ore fino a tre ore":2,
                 "meno di un'ora":1}
 
nomi_var = df.columns.tolist()
for var in nomi_var:
    if 'm_p_' in var:
        df[var] = df[var].replace(diz_aliases_freq)
        

diz_aliases_comp = {
                 0:0,
                 'inferiore':-1,
                 'uguale':0,
                 "maggiore":1,
                 'nan':0
                 }
 
df['m_op_disorientamento_realta_quotidiana_vs_3anniFa'] = df['m_op_disorientamento_realta_quotidiana_vs_3anniFa'].replace(diz_aliases_comp)


diz_aliases_situazEconomic = {
    'rimasta la stessa': 0,
    'peggiorata': -1,
    'non sa/non risponde': 0,
    'nan': 0,
    'migliorata': 1
}
df['m_op_situazEconomic_propria_ultimi10anni'] = df['m_op_situazEconomic_propria_ultimi10anni'].replace(diz_aliases_situazEconomic)


diz_aliases_futEconomic = {
    'peggiorare': -1,
    'rimanere la stessa': 0,
    'non sa/non risponde': 0,
    'nan': 0,
    'migliorare': 1
}
df['m_op_situazEconomic_futura'] = df['m_op_situazEconomic_futura'].replace(diz_aliases_futEconomic)


diz_aliases_abo = {
    'una cattiva legge': -1,
    'una legge buona ma che va cambiata': 1,
    'una buona legge': 1,
    'non saprei/preferisco non rispondere': 0,
    'nan': 0
}

df['m_op_legge_aborto_1987'] = df['m_op_legge_aborto_1987'].replace(diz_aliases_abo)


diz_aliases_eut = {
    'no': -1,
    'si': 2,
    'non sa/non risponde': 0,
    'dipende dalle condizioni':1
}

df['m_op_favore_eutanasia_a_determinate_condizioni'] = df['m_op_favore_eutanasia_a_determinate_condizioni'].replace(diz_aliases_eut)


diz_aliases_identita = {
    "piu' europeo che italiano": 2,
    'sia italiano che europeo': 1,
    'solo italiano': -2,
    "piu' italiano che europeo": -1,
    'non sa - non risponde': 0,
    'solo europeo': 2,
    'nan': 0
}
df['m_op_sentimento_italianoVSeuropeo'] = df['m_op_sentimento_italianoVSeuropeo'].replace(diz_aliases_identita)


diz_aliases_modernizzazione = {
    'si sta modernizzando': 1,
    'sta regredendo': -1,
    'non sa/non risponde': 0,
    'nan': 0
}
df['m_modernizz_vs_regress_Paese'] = df['m_modernizz_vs_regress_Paese'].replace(diz_aliases_modernizzazione)


diz_aliases_vantaggi = {
    "piu' vantaggi": 1,
    'vantaggi e svantaggi in egual misura': 0,
    "piu' svantaggi": -1,
    "ne' vantaggi ne' svantaggi": 0,
    'non sa/non risponde': 0,
    'nan': None
}
df['m_op_partecipazione_in_UE'] = df['m_op_partecipazione_in_UE'].replace(diz_aliases_vantaggi)


diz_aliases_livello = {
    'bassa': -1,
    'media': 1,
    'alta': 2,
    0: 0,
    'nan': None
}
nomi_var = df.columns.tolist()
for var in nomi_var:
    if 'm_op_attenzione_' in var:
        df[var] = df[var].replace(diz_aliases_livello)
        
        
diz_aliases_andamento = {
    'rimasta uguale': 0,
    'peggiorata': -1,
    'migliorata': 1,
    0: 0,
    'nan': None
}
df['m_op_scuolaPubblica_ultimiAnni'] = df['m_op_scuolaPubblica_ultimiAnni'].replace(diz_aliases_andamento)


diz_aliases_quantita = {
    1: 1,
    'poca&nbsp;': -1,
    'molta': 2,
    'nessuna': -2,
    0: 0,
    'nan': None
}
nomi_var = df.columns.tolist()
for var in nomi_var:
    if 'm_op_fiducia_' in var:
        df[var] = df[var].replace(diz_aliases_quantita)
        
        
diz_aliases_postoStabile = {
    "d'accordo": 1,
    'in disaccordo': -1,
    "del tutto d'accordo": 2,
    'del tutto in disaccordo': -2,
    'preferisco non rispondere': 0,
    'nan': None
}
df['m_op_rinuncie_per_postoStabile'] = df['m_op_rinuncie_per_postoStabile'].replace(diz_aliases_postoStabile)


diz_aliases_pop = {
    'molti danni': 2,
    'nessun danno': 0,
    'qualche danno': 1,
    0: 0,
    'nan': None
}
df['m_op_danni_populismo_in_italia'] = df['m_op_danni_populismo_in_italia'].replace(diz_aliases_pop)
# Out:
# C:\Users\lucap\AppData\Local\Temp\ipykernel_22928\2500494670.py:21: FutureWarning: Downcasting behavior in `replace` is deprecated and will be removed in a future version. To retain the old behavior, explicitly call `result.infer_objects(copy=False)`. To opt-in to the future behavior, set `pd.set_option('future.no_silent_downcasting', True)`
#   df[var] = df[var].replace(diz_aliases_ac)
# C:\Users\lucap\AppData\Local\Temp\ipykernel_22928\2500494670.py:35: FutureWarning: Downcasting behavior in `replace` is deprecated and will be removed in a future version. To retain the old behavior, explicitly call `result.infer_objects(copy=False)`. To opt-in to the future behavior, set `pd.set_option('future.no_silent_downcasting', True)`
#   df[var] = df[var].replace(diz_aliases_op)
# C:\Users\lucap\AppData\Local\Temp\ipykernel_22928\2500494670.py:47: FutureWarning: Downcasting behavior in `replace` is deprecated and will be removed in a future version. To retain the old behavior, explicitly call `result.infer_objects(copy=False)`. To opt-in to the future behavior, set `pd.set_option('future.no_silent_downcasting', True)`
#   df[var] = df[var].replace(diz_aliases_trend)
# C:\Users\lucap\AppData\Local\Temp\ipykernel_22928\2500494670.py:63: FutureWarning: Downcasting behavior in `replace` is deprecated and will be removed in a future version. To retain the old behavior, explicitly call `result.infer_objects(copy=False)`. To opt-in to the future behavior, set `pd.set_option('future.no_silent_downcasting', True)`
#   df['m_p_scolarita'] = df['m_p_scolarita'].replace(diz_aliases_scol)
# C:\Users\lucap\AppData\Local\Temp\ipykernel_22928\2500494670.py:75: FutureWarning: Downcasting behavior in `replace` is deprecated and will be removed in a future version. To retain the old behavior, explicitly call `result.infer_objects(copy=False)`. To opt-in to the future behavior, set `pd.set_option('future.no_silent_downcasting', True)`
#   df['m_p_r_ampiezza6'] = df['m_p_r_ampiezza6'].replace(diz_aliases_geo)
# C:\Users\lucap\AppData\Local\Temp\ipykernel_22928\2500494670.py:85: FutureWarning: Downcasting behavior in `replace` is deprecated and will be removed in a future version. To retain the old behavior, explicitly call `result.infer_objects(copy=False)`. To opt-in to the future behavior, set `pd.set_option('future.no_silent_downcasting', True)`
#   df['m_op_come_reddito_consenteDiVivere'] = df['m_op_come_reddito_consenteDiVivere'].replace(diz_aliases_eco)
# C:\Users\lucap\AppData\Local\Temp\ipykernel_22928\2500494670.py:112: FutureWarning: Downcasting behavior in `replace` is deprecated and will be removed in a future version. To retain the old behavior, explicitly call `result.infer_objects(copy=False)`. To opt-in to the future behavior, set `pd.set_option('future.no_silent_downcasting', True)`
#   df[var] = df[var].replace(diz_aliases_freq_y)
# C:\Users\lucap\AppData\Local\Temp\ipykernel_22928\2500494670.py:126: FutureWarning: Downcasting behavior in `replace` is deprecated and will be removed in a future version. To retain the old behavior, explicitly call `result.infer_objects(copy=False)`. To opt-in to the future behavior, set `pd.set_option('future.no_silent_downcasting', True)`
#   df[var] = df[var].replace(diz_aliases_freq)
# C:\Users\lucap\AppData\Local\Temp\ipykernel_22928\2500494670.py:137: FutureWarning: Downcasting behavior in `replace` is deprecated and will be removed in a future version. To retain the old behavior, explicitly call `result.infer_objects(copy=False)`. To opt-in to the future behavior, set `pd.set_option('future.no_silent_downcasting', True)`
#   df['m_op_disorientamento_realta_quotidiana_vs_3anniFa'] = df['m_op_disorientamento_realta_quotidiana_vs_3anniFa'].replace(diz_aliases_comp)
# C:\Users\lucap\AppData\Local\Temp\ipykernel_22928\2500494670.py:147: FutureWarning: Downcasting behavior in `replace` is deprecated and will be removed in a future version. To retain the old behavior, explicitly call `result.infer_objects(copy=False)`. To opt-in to the future behavior, set `pd.set_option('future.no_silent_downcasting', True)`
#   df['m_op_situazEconomic_propria_ultimi10anni'] = df['m_op_situazEconomic_propria_ultimi10anni'].replace(diz_aliases_situazEconomic)
# C:\Users\lucap\AppData\Local\Temp\ipykernel_22928\2500494670.py:157: FutureWarning: Downcasting behavior in `replace` is deprecated and will be removed in a future version. To retain the old behavior, explicitly call `result.infer_objects(copy=False)`. To opt-in to the future behavior, set `pd.set_option('future.no_silent_downcasting', True)`
#   df['m_op_situazEconomic_futura'] = df['m_op_situazEconomic_futura'].replace(diz_aliases_futEconomic)
# C:\Users\lucap\AppData\Local\Temp\ipykernel_22928\2500494670.py:168: FutureWarning: Downcasting behavior in `replace` is deprecated and will be removed in a future version. To retain the old behavior, explicitly call `result.infer_objects(copy=False)`. To opt-in to the future behavior, set `pd.set_option('future.no_silent_downcasting', True)`
#   df['m_op_legge_aborto_1987'] = df['m_op_legge_aborto_1987'].replace(diz_aliases_abo)
# C:\Users\lucap\AppData\Local\Temp\ipykernel_22928\2500494670.py:178: FutureWarning: Downcasting behavior in `replace` is deprecated and will be removed in a future version. To retain the old behavior, explicitly call `result.infer_objects(copy=False)`. To opt-in to the future behavior, set `pd.set_option('future.no_silent_downcasting', True)`
#   df['m_op_favore_eutanasia_a_determinate_condizioni'] = df['m_op_favore_eutanasia_a_determinate_condizioni'].replace(diz_aliases_eut)
# C:\Users\lucap\AppData\Local\Temp\ipykernel_22928\2500494670.py:190: FutureWarning: Downcasting behavior in `replace` is deprecated and will be removed in a future version. To retain the old behavior, explicitly call `result.infer_objects(copy=False)`. To opt-in to the future behavior, set `pd.set_option('future.no_silent_downcasting', True)`
#   df['m_op_sentimento_italianoVSeuropeo'] = df['m_op_sentimento_italianoVSeuropeo'].replace(diz_aliases_identita)
# C:\Users\lucap\AppData\Local\Temp\ipykernel_22928\2500494670.py:199: FutureWarning: Downcasting behavior in `replace` is deprecated and will be removed in a future version. To retain the old behavior, explicitly call `result.infer_objects(copy=False)`. To opt-in to the future behavior, set `pd.set_option('future.no_silent_downcasting', True)`
#   df['m_modernizz_vs_regress_Paese'] = df['m_modernizz_vs_regress_Paese'].replace(diz_aliases_modernizzazione)
# C:\Users\lucap\AppData\Local\Temp\ipykernel_22928\2500494670.py:210: FutureWarning: Downcasting behavior in `replace` is deprecated and will be removed in a future version. To retain the old behavior, explicitly call `result.infer_objects(copy=False)`. To opt-in to the future behavior, set `pd.set_option('future.no_silent_downcasting', True)`
#   df['m_op_partecipazione_in_UE'] = df['m_op_partecipazione_in_UE'].replace(diz_aliases_vantaggi)
# C:\Users\lucap\AppData\Local\Temp\ipykernel_22928\2500494670.py:223: FutureWarning: Downcasting behavior in `replace` is deprecated and will be removed in a future version. To retain the old behavior, explicitly call `result.infer_objects(copy=False)`. To opt-in to the future behavior, set `pd.set_option('future.no_silent_downcasting', True)`
#   df[var] = df[var].replace(diz_aliases_livello)
# C:\Users\lucap\AppData\Local\Temp\ipykernel_22928\2500494670.py:233: FutureWarning: Downcasting behavior in `replace` is deprecated and will be removed in a future version. To retain the old behavior, explicitly call `result.infer_objects(copy=False)`. To opt-in to the future behavior, set `pd.set_option('future.no_silent_downcasting', True)`
#   df['m_op_scuolaPubblica_ultimiAnni'] = df['m_op_scuolaPubblica_ultimiAnni'].replace(diz_aliases_andamento)
# C:\Users\lucap\AppData\Local\Temp\ipykernel_22928\2500494670.py:247: FutureWarning: Downcasting behavior in `replace` is deprecated and will be removed in a future version. To retain the old behavior, explicitly call `result.infer_objects(copy=False)`. To opt-in to the future behavior, set `pd.set_option('future.no_silent_downcasting', True)`
#   df[var] = df[var].replace(diz_aliases_quantita)
# C:\Users\lucap\AppData\Local\Temp\ipykernel_22928\2500494670.py:258: FutureWarning: Downcasting behavior in `replace` is deprecated and will be removed in a future version. To retain the old behavior, explicitly call `result.infer_objects(copy=False)`. To opt-in to the future behavior, set `pd.set_option('future.no_silent_downcasting', True)`
#   df['m_op_rinuncie_per_postoStabile'] = df['m_op_rinuncie_per_postoStabile'].replace(diz_aliases_postoStabile)
# C:\Users\lucap\AppData\Local\Temp\ipykernel_22928\2500494670.py:268: FutureWarning: Downcasting behavior in `replace` is deprecated and will be removed in a future version. To retain the old behavior, explicitly call `result.infer_objects(copy=False)`. To opt-in to the future behavior, set `pd.set_option('future.no_silent_downcasting', True)`
#   df['m_op_danni_populismo_in_italia'] = df['m_op_danni_populismo_in_italia'].replace(diz_aliases_pop)

# %%
df.shape
# Out:
# (3319, 189)

# %%
df = df.fillna(0)

# %%
df.columns = df.columns.str.replace(' ', '_')
df.columns = df.columns.str.replace('à', 'a')
df.columns = df.columns.str.replace('[^a-zA-Z0-9_]', '').str.replace(' ', '_')
df.columns = df.columns.str.replace('[()\']+|,\s*', '', regex=True)
# Out:
# <>:4: SyntaxWarning: invalid escape sequence '\s'
# <>:4: SyntaxWarning: invalid escape sequence '\s'
# C:\Users\lucap\AppData\Local\Temp\ipykernel_22928\3965184111.py:4: SyntaxWarning: invalid escape sequence '\s'
#   df.columns = df.columns.str.replace('[()\']+|,\s*', '', regex=True)

# %% [markdown]
# # Classifiers

# %%
# provo a rimuovere le righe con i valori Nan poiché solo 285
df = df.dropna()

# %%
X = df.drop(columns = ['m_p_int_voto'])
y = df.m_p_int_voto

# %%
X_numerico = X.select_dtypes(include=['float64', 'int64'])

# %%
# 1) Creiamo le maschere booleane
mask_train = X["m_anno_indagine"].isin([2017, 2018])   # True per 2017–18
mask_test  = X["m_anno_indagine"] == 2019              # True per 2019

# 2) Applichiamo le maschere
X_train = X.loc[mask_train].copy()
X_test  = X.loc[mask_test].copy()
y_train = y.loc[mask_train].copy()
y_test  = y.loc[mask_test].copy()

# 3) (Opzionale) Rimuovere 'm_anno_indagine' dalle feature
X_train = X_train.drop(columns=["m_anno_indagine"])
X_test  = X_test.drop(columns=["m_anno_indagine"])

# 4) (Opzionale) Reindicizzare
X_train.reset_index(drop=True, inplace=True)
X_test.reset_index(drop=True, inplace=True)
y_train.reset_index(drop=True, inplace=True)
y_test.reset_index(drop=True, inplace=True)

# %%
from sklearn.preprocessing import LabelEncoder

le = LabelEncoder()
y_train_enc = le.fit_transform(y_train)     # usa SOLO il train!
y_test_enc  = le.transform(y_test)          # da usare nel test finale

N_CLASSES = len(le.classes_)                # servirà a XGBoost / LightGBM

# %%
X_train.shape, X_test.shape, y_train.shape, y_test.shape
# Out:
# ((2164, 187), (1155, 187), (2164,), (1155,))

# %%
from sklearn.model_selection import StratifiedKFold
from sklearn.metrics import make_scorer, f1_score

cv = StratifiedKFold(n_splits=10, shuffle=True, random_state=42)
scorer = make_scorer(f1_score, average='macro')   # macro-F1 adatto al multiclasse

# %%
def objective(trial):
    model_name = trial.suggest_categorical('model', ['lgbm', 'xgb', 'dt', 'rf'])
    
    # ---------------- LIGHTGBM ----------------
    if model_name == 'lgbm':
        model = lgb.LGBMClassifier(
            objective='multiclass',
            num_class=N_CLASSES,
            n_jobs=4,
            random_state=42,
            learning_rate=trial.suggest_float('lgb_lr', 0.01, 0.2, log=True),
            n_estimators=trial.suggest_int('lgb_est', 100, 1000),
            num_leaves=trial.suggest_int('lgb_leaves', 31, 255),
            feature_fraction=trial.suggest_float('lgb_ff', 0.6, 1.0),
            bagging_fraction=trial.suggest_float('lgb_bf', 0.5, 1.0),
            bagging_freq=trial.suggest_int('lgb_freq', 0, 5),
            reg_alpha=trial.suggest_float('lgb_alpha', 1e-8, 10.0, log=True),
            reg_lambda=trial.suggest_float('lgb_lambda', 1e-8, 10.0, log=True)
        )

    # ---------------- XGBOOST ------------------
    elif model_name == 'xgb':
        model = XGBClassifier(
            objective='multi:softprob',
            num_class=N_CLASSES,
            tree_method='hist',
            n_jobs=4,
            random_state=42,
            eval_metric='mlogloss',
            learning_rate=trial.suggest_float('xgb_lr', 0.01, 0.2, log=True),
            n_estimators=trial.suggest_int('xgb_est', 100, 1000),
            max_depth=trial.suggest_int('xgb_depth', 3, 12),
            min_child_weight=trial.suggest_float('xgb_mc', 1e-3, 10.0, log=True),
            subsample=trial.suggest_float('xgb_sub', 0.5, 1.0),
            colsample_bytree=trial.suggest_float('xgb_col', 0.5, 1.0),
            gamma=trial.suggest_float('xgb_gamma', 0.0, 5.0),
            reg_alpha=trial.suggest_float('xgb_alpha', 1e-8, 10.0, log=True),
            reg_lambda=trial.suggest_float('xgb_lambda', 1e-8, 10.0, log=True)
        )

    # ---------------- DECISION TREE -----------
    elif model_name == 'dt':
        model = DecisionTreeClassifier(
            random_state=42,
            criterion=trial.suggest_categorical('dt_crit', ['gini', 'entropy']),
            max_depth=trial.suggest_int('dt_depth', 2, 20),
            min_samples_split=trial.suggest_int('dt_split', 2, 20),
            min_samples_leaf=trial.suggest_int('dt_leaf', 1, 20)
        )

    # ---------------- RANDOM FOREST -----------
    else:  # 'rf'
        model = RandomForestClassifier(
            random_state=42,
            n_jobs=-1,
            n_estimators=trial.suggest_int('rf_estimators', 100, 1000),
            max_depth=trial.suggest_int('rf_depth', 5, 30),
            min_samples_split=trial.suggest_int('rf_split', 2, 20),
            min_samples_leaf=trial.suggest_int('rf_leaf', 1, 20),
            max_features=trial.suggest_categorical('rf_maxfeat',
                                                   ['sqrt', 'log2', None]),
            bootstrap=trial.suggest_categorical('rf_bootstrap',
                                                [True, False])
        )

    # ---- CV evaluation (macro-F1) ------------
    score = cross_val_score(model, X_train, y_train_enc,
                            cv=cv, scoring=scorer,
                            n_jobs=-1).mean()
    return score

# %%
study = optuna.create_study(direction='maximize')
study.optimize(objective, n_trials=200, timeout=7200)   # ↑ trials se vuoi più esplorazione

print("Best macro-F1:", study.best_value)
print("Best params :", study.best_params)
# Out:
# [I 2025-07-24 16:48:42,458] A new study created in memory with name: no-name-0e7df849-aa5d-47e5-8ad2-1b76854d494c
# [I 2025-07-24 16:49:11,336] Trial 0 finished with value: 0.6339363079138487 and parameters: {'model': 'lgbm', 'lgb_lr': 0.15447251587669514, 'lgb_est': 498, 'lgb_leaves': 131, 'lgb_ff': 0.9967782388148909, 'lgb_bf': 0.9844678729759267, 'lgb_freq': 3, 'lgb_alpha': 0.00017483369415221257, 'lgb_lambda': 5.707067700136496e-07}. Best is trial 0 with value: 0.6339363079138487.
# [I 2025-07-24 16:49:55,607] Trial 1 finished with value: 0.6363449077875044 and parameters: {'model': 'lgbm', 'lgb_lr': 0.11332049602919164, 'lgb_est': 982, 'lgb_leaves': 251, 'lgb_ff': 0.6066160042906404, 'lgb_bf': 0.7850683607406344, 'lgb_freq': 5, 'lgb_alpha': 1.2807499533035894e-06, 'lgb_lambda': 0.010546114955456405}. Best is trial 1 with value: 0.6363449077875044.
# [I 2025-07-24 16:49:57,089] Trial 2 finished with value: 0.6447342440105562 and parameters: {'model': 'xgb', 'xgb_lr': 0.08959006199962875, 'xgb_est': 132, 'xgb_depth': 5, 'xgb_mc': 0.29658769637329413, 'xgb_sub': 0.6934331001576548, 'xgb_col': 0.5933390565256498, 'xgb_gamma': 2.6807818738421814, 'xgb_alpha': 0.006518581456816889, 'xgb_lambda': 2.751292384030055e-06}. Best is trial 2 with value: 0.6447342440105562.
# [I 2025-07-24 16:49:57,679] Trial 3 finished with value: 0.5366033778110907 and parameters: {'model': 'dt', 'dt_crit': 'gini', 'dt_depth': 12, 'dt_split': 20, 'dt_leaf': 20}. Best is trial 2 with value: 0.6447342440105562.
# [I 2025-07-24 16:50:01,399] Trial 4 finished with value: 0.6433550869292561 and parameters: {'model': 'xgb', 'xgb_lr': 0.04859597612822505, 'xgb_est': 251, 'xgb_depth': 9, 'xgb_mc': 5.359238772225692, 'xgb_sub': 0.608262329621297, 'xgb_col': 0.56276214851835, 'xgb_gamma': 0.49036126909255184, 'xgb_alpha': 0.9242547133757973, 'xgb_lambda': 0.0008796853319422334}. Best is trial 2 with value: 0.6447342440105562.
# [I 2025-07-24 16:50:18,660] Trial 5 finished with value: 0.6314079860562503 and parameters: {'model': 'lgbm', 'lgb_lr': 0.024118824773365865, 'lgb_est': 217, 'lgb_leaves': 232, 'lgb_ff': 0.6537961345137863, 'lgb_bf': 0.9571304532118756, 'lgb_freq': 4, 'lgb_alpha': 2.1587238290250558e-06, 'lgb_lambda': 5.505670709236266e-08}. Best is trial 2 with value: 0.6447342440105562.
# [I 2025-07-24 16:50:30,691] Trial 6 finished with value: 0.6091378941508905 and parameters: {'model': 'rf', 'rf_estimators': 217, 'rf_depth': 18, 'rf_split': 7, 'rf_leaf': 12, 'rf_maxfeat': None, 'rf_bootstrap': True}. Best is trial 2 with value: 0.6447342440105562.
# [I 2025-07-24 16:50:31,106] Trial 7 finished with value: 0.5402947615166671 and parameters: {'model': 'dt', 'dt_crit': 'gini', 'dt_depth': 10, 'dt_split': 2, 'dt_leaf': 8}. Best is trial 2 with value: 0.6447342440105562.
# [I 2025-07-24 16:50:31,344] Trial 8 finished with value: 0.5482110185923309 and parameters: {'model': 'dt', 'dt_crit': 'gini', 'dt_depth': 5, 'dt_split': 13, 'dt_leaf': 5}. Best is trial 2 with value: 0.6447342440105562.
# [I 2025-07-24 16:50:31,738] Trial 9 finished with value: 0.518430528439544 and parameters: {'model': 'dt', 'dt_crit': 'entropy', 'dt_depth': 17, 'dt_split': 18, 'dt_leaf': 5}. Best is trial 2 with value: 0.6447342440105562.
# [I 2025-07-24 16:50:36,524] Trial 10 finished with value: 0.6320711067829199 and parameters: {'model': 'xgb', 'xgb_lr': 0.19891591093518385, 'xgb_est': 850, 'xgb_depth': 3, 'xgb_mc': 0.020935146012641244, 'xgb_sub': 0.8807051026448901, 'xgb_col': 0.6899779223203537, 'xgb_gamma': 4.01270567565469, 'xgb_alpha': 6.870788939088728e-06, 'xgb_lambda': 1.262770469597887e-08}. Best is trial 2 with value: 0.6447342440105562.
# [I 2025-07-24 16:50:38,415] Trial 11 finished with value: 0.6451678051318547 and parameters: {'model': 'xgb', 'xgb_lr': 0.0514370147621969, 'xgb_est': 111, 'xgb_depth': 9, 'xgb_mc': 7.449767676268975, 'xgb_sub': 0.5782839601058218, 'xgb_col': 0.5092965842499348, 'xgb_gamma': 0.5913421004877395, 'xgb_alpha': 1.238482517600791, 'xgb_lambda': 0.0014636326915462275}. Best is trial 11 with value: 0.6451678051318547.
# [I 2025-07-24 16:50:39,897] Trial 12 finished with value: 0.6395557486970339 and parameters: {'model': 'xgb', 'xgb_lr': 0.06162113353899274, 'xgb_est': 117, 'xgb_depth': 6, 'xgb_mc': 3.7240716670511556, 'xgb_sub': 0.5894145652549463, 'xgb_col': 0.5062926953040237, 'xgb_gamma': 1.9215560055935623, 'xgb_alpha': 1.0565158035210858, 'xgb_lambda': 6.897838631023384e-06}. Best is trial 11 with value: 0.6451678051318547.
# [I 2025-07-24 16:50:41,406] Trial 13 finished with value: 0.6324979217405653 and parameters: {'model': 'xgb', 'xgb_lr': 0.08541262825490957, 'xgb_est': 104, 'xgb_depth': 12, 'xgb_mc': 0.20569567373576234, 'xgb_sub': 0.7084143664597173, 'xgb_col': 0.9948677833569672, 'xgb_gamma': 2.541069018871062, 'xgb_alpha': 0.005414284166794419, 'xgb_lambda': 0.8923027039635804}. Best is trial 11 with value: 0.6451678051318547.
# [I 2025-07-24 16:50:49,695] Trial 14 finished with value: 0.6427693275866619 and parameters: {'model': 'xgb', 'xgb_lr': 0.01379671031744788, 'xgb_est': 429, 'xgb_depth': 7, 'xgb_mc': 0.3754796449886917, 'xgb_sub': 0.5307820952874356, 'xgb_col': 0.6413328229662365, 'xgb_gamma': 0.357667950009688, 'xgb_alpha': 0.0032210776406579327, 'xgb_lambda': 0.00016772618081885806}. Best is trial 11 with value: 0.6451678051318547.
# [I 2025-07-24 16:50:56,566] Trial 15 finished with value: 0.5393586278469338 and parameters: {'model': 'rf', 'rf_estimators': 909, 'rf_depth': 6, 'rf_split': 20, 'rf_leaf': 1, 'rf_maxfeat': 'log2', 'rf_bootstrap': False}. Best is trial 11 with value: 0.6451678051318547.
# [I 2025-07-24 16:51:00,223] Trial 16 finished with value: 0.6286471019039251 and parameters: {'model': 'xgb', 'xgb_lr': 0.019234870136807237, 'xgb_est': 461, 'xgb_depth': 4, 'xgb_mc': 0.0012996635392389492, 'xgb_sub': 0.7416058616670406, 'xgb_col': 0.5053875832428201, 'xgb_gamma': 2.408301302291651, 'xgb_alpha': 4.77200736693525, 'xgb_lambda': 1.5308178784777508e-06}. Best is trial 11 with value: 0.6451678051318547.
# [I 2025-07-24 16:51:04,671] Trial 17 finished with value: 0.6419305355516082 and parameters: {'model': 'xgb', 'xgb_lr': 0.11351398086451704, 'xgb_est': 751, 'xgb_depth': 10, 'xgb_mc': 0.9337920982112076, 'xgb_sub': 0.6637847929793164, 'xgb_col': 0.8323306164852797, 'xgb_gamma': 3.797832313052985, 'xgb_alpha': 2.280354544927698e-08, 'xgb_lambda': 0.028132032921841254}. Best is trial 11 with value: 0.6451678051318547.
# [I 2025-07-24 16:51:07,719] Trial 18 finished with value: 0.6419339258936102 and parameters: {'model': 'xgb', 'xgb_lr': 0.031390928836497065, 'xgb_est': 291, 'xgb_depth': 5, 'xgb_mc': 0.030482745186206854, 'xgb_sub': 0.859540491104215, 'xgb_col': 0.6125899218368714, 'xgb_gamma': 1.4516299190253248, 'xgb_alpha': 0.01981876863606229, 'xgb_lambda': 4.1048551913836444e-07}. Best is trial 11 with value: 0.6451678051318547.
# [I 2025-07-24 16:51:16,315] Trial 19 finished with value: 0.5738275836761286 and parameters: {'model': 'rf', 'rf_estimators': 987, 'rf_depth': 30, 'rf_split': 2, 'rf_leaf': 20, 'rf_maxfeat': 'sqrt', 'rf_bootstrap': True}. Best is trial 11 with value: 0.6451678051318547.
# [I 2025-07-24 16:51:20,654] Trial 20 finished with value: 0.6352183907696303 and parameters: {'model': 'xgb', 'xgb_lr': 0.030538548862151994, 'xgb_est': 629, 'xgb_depth': 9, 'xgb_mc': 1.4980001748020768, 'xgb_sub': 0.996583336702673, 'xgb_col': 0.7636486708834285, 'xgb_gamma': 3.0515689575748906, 'xgb_alpha': 4.899832371151268e-05, 'xgb_lambda': 0.0003413822529863426}. Best is trial 11 with value: 0.6451678051318547.
# [I 2025-07-24 16:51:23,978] Trial 21 finished with value: 0.642976338159956 and parameters: {'model': 'xgb', 'xgb_lr': 0.049933608573301536, 'xgb_est': 218, 'xgb_depth': 9, 'xgb_mc': 8.891339203693306, 'xgb_sub': 0.6005486093803192, 'xgb_col': 0.5666421574834145, 'xgb_gamma': 0.03734226164323251, 'xgb_alpha': 0.44258859624738245, 'xgb_lambda': 0.002556051874481576}. Best is trial 11 with value: 0.6451678051318547.
# [I 2025-07-24 16:51:26,843] Trial 22 finished with value: 0.6408129270753198 and parameters: {'model': 'xgb', 'xgb_lr': 0.0840162863117713, 'xgb_est': 309, 'xgb_depth': 8, 'xgb_mc': 8.663924481825735, 'xgb_sub': 0.6150260111154973, 'xgb_col': 0.5755315835383412, 'xgb_gamma': 1.2892777482293707, 'xgb_alpha': 0.09453112943306251, 'xgb_lambda': 0.01607895502545962}. Best is trial 11 with value: 0.6451678051318547.
# [I 2025-07-24 16:51:28,331] Trial 23 finished with value: 0.6342071070927562 and parameters: {'model': 'xgb', 'xgb_lr': 0.04227404674484649, 'xgb_est': 100, 'xgb_depth': 11, 'xgb_mc': 1.604033142089761, 'xgb_sub': 0.5053329898059801, 'xgb_col': 0.5048383052653079, 'xgb_gamma': 0.839345850710889, 'xgb_alpha': 6.52611737572872, 'xgb_lambda': 3.593040761955225e-05}. Best is trial 11 with value: 0.6451678051318547.
# [I 2025-07-24 16:51:31,034] Trial 24 finished with value: 0.6475768636811958 and parameters: {'model': 'xgb', 'xgb_lr': 0.12903735363709418, 'xgb_est': 257, 'xgb_depth': 7, 'xgb_mc': 0.05957415266082655, 'xgb_sub': 0.6651793078897192, 'xgb_col': 0.6582903738332289, 'xgb_gamma': 0.8063628778835321, 'xgb_alpha': 0.1721436175233285, 'xgb_lambda': 0.002077730934950017}. Best is trial 24 with value: 0.6475768636811958.
# [I 2025-07-24 16:51:33,484] Trial 25 finished with value: 0.6302806432592531 and parameters: {'model': 'xgb', 'xgb_lr': 0.1522534883449455, 'xgb_est': 355, 'xgb_depth': 6, 'xgb_mc': 0.04296255824816492, 'xgb_sub': 0.7946544628742906, 'xgb_col': 0.7160448807258718, 'xgb_gamma': 4.9902611083654715, 'xgb_alpha': 0.0004565399819304165, 'xgb_lambda': 0.1585271033375078}. Best is trial 24 with value: 0.6475768636811958.
# [I 2025-07-24 16:51:35,646] Trial 26 finished with value: 0.6482841143837708 and parameters: {'model': 'xgb', 'xgb_lr': 0.10265191612877458, 'xgb_est': 208, 'xgb_depth': 7, 'xgb_mc': 0.008449711273799754, 'xgb_sub': 0.6825719466098982, 'xgb_col': 0.6428960541645435, 'xgb_gamma': 1.2059795186673736, 'xgb_alpha': 0.08653935705679981, 'xgb_lambda': 0.006032735792554157}. Best is trial 26 with value: 0.6482841143837708.
# [I 2025-07-24 16:51:44,586] Trial 27 finished with value: 0.5430722124852376 and parameters: {'model': 'rf', 'rf_estimators': 121, 'rf_depth': 7, 'rf_split': 19, 'rf_leaf': 2, 'rf_maxfeat': None, 'rf_bootstrap': False}. Best is trial 26 with value: 0.6482841143837708.
# [I 2025-07-24 16:52:00,782] Trial 28 finished with value: 0.6492903077871958 and parameters: {'model': 'lgbm', 'lgb_lr': 0.01275149059332685, 'lgb_est': 984, 'lgb_leaves': 40, 'lgb_ff': 0.9031180314206431, 'lgb_bf': 0.5084666617636349, 'lgb_freq': 1, 'lgb_alpha': 8.215798304313068, 'lgb_lambda': 6.676052597298147}. Best is trial 28 with value: 0.6492903077871958.
# [I 2025-07-24 16:52:23,015] Trial 29 finished with value: 0.6367194137593392 and parameters: {'model': 'lgbm', 'lgb_lr': 0.010471775329287994, 'lgb_est': 942, 'lgb_leaves': 32, 'lgb_ff': 0.9054464401628787, 'lgb_bf': 0.5033901252293822, 'lgb_freq': 0, 'lgb_alpha': 9.777136522045666, 'lgb_lambda': 9.20574982740848}. Best is trial 28 with value: 0.6492903077871958.
# [I 2025-07-24 16:52:47,531] Trial 30 finished with value: 0.6445613467762923 and parameters: {'model': 'lgbm', 'lgb_lr': 0.01074830015651936, 'lgb_est': 673, 'lgb_leaves': 33, 'lgb_ff': 0.8149970533525066, 'lgb_bf': 0.5033608411524209, 'lgb_freq': 0, 'lgb_alpha': 4.446722177348163, 'lgb_lambda': 9.767703486097941}. Best is trial 28 with value: 0.6492903077871958.
# [I 2025-07-24 16:53:16,833] Trial 31 finished with value: 0.6382708435019099 and parameters: {'model': 'lgbm', 'lgb_lr': 0.04220176618813524, 'lgb_est': 711, 'lgb_leaves': 110, 'lgb_ff': 0.8034861456206197, 'lgb_bf': 0.6690388545317534, 'lgb_freq': 2, 'lgb_alpha': 0.021744348538657567, 'lgb_lambda': 0.0006677763148953997}. Best is trial 28 with value: 0.6492903077871958.
# [I 2025-07-24 16:53:22,190] Trial 32 finished with value: 0.6455922246213845 and parameters: {'model': 'lgbm', 'lgb_lr': 0.023022885203682668, 'lgb_est': 109, 'lgb_leaves': 84, 'lgb_ff': 0.9449017958458454, 'lgb_bf': 0.6691502786305883, 'lgb_freq': 2, 'lgb_alpha': 0.029541282810913755, 'lgb_lambda': 0.05858268539086902}. Best is trial 28 with value: 0.6492903077871958.
# [I 2025-07-24 16:53:28,978] Trial 33 finished with value: 0.6378527540320468 and parameters: {'model': 'lgbm', 'lgb_lr': 0.024443154723092966, 'lgb_est': 141, 'lgb_leaves': 85, 'lgb_ff': 0.9475872309055672, 'lgb_bf': 0.6541954380339787, 'lgb_freq': 2, 'lgb_alpha': 0.02854554949448213, 'lgb_lambda': 0.071702892376927}. Best is trial 28 with value: 0.6492903077871958.
# [I 2025-07-24 16:53:45,342] Trial 34 finished with value: 0.6430296215625475 and parameters: {'model': 'lgbm', 'lgb_lr': 0.020901597424174547, 'lgb_est': 384, 'lgb_leaves': 79, 'lgb_ff': 0.8812881074024098, 'lgb_bf': 0.6308130262960057, 'lgb_freq': 1, 'lgb_alpha': 0.08436227527530951, 'lgb_lambda': 0.23937985398288167}. Best is trial 28 with value: 0.6492903077871958.
# [I 2025-07-24 16:54:11,223] Trial 35 finished with value: 0.6424722876165967 and parameters: {'model': 'lgbm', 'lgb_lr': 0.017635686491515777, 'lgb_est': 337, 'lgb_leaves': 172, 'lgb_ff': 0.8752629376730414, 'lgb_bf': 0.8040060489038185, 'lgb_freq': 1, 'lgb_alpha': 0.0003483319323479087, 'lgb_lambda': 2.6926242959394915e-05}. Best is trial 28 with value: 0.6492903077871958.
# [I 2025-07-24 16:54:35,064] Trial 36 finished with value: 0.6394881733441731 and parameters: {'model': 'lgbm', 'lgb_lr': 0.055427402237603667, 'lgb_est': 775, 'lgb_leaves': 68, 'lgb_ff': 0.9869570650811413, 'lgb_bf': 0.590822169500306, 'lgb_freq': 3, 'lgb_alpha': 0.18931141221044417, 'lgb_lambda': 0.4947631689625157}. Best is trial 28 with value: 0.6492903077871958.
# [I 2025-07-24 16:55:06,952] Trial 37 finished with value: 0.6395193965933393 and parameters: {'model': 'lgbm', 'lgb_lr': 0.04438302435594801, 'lgb_est': 556, 'lgb_leaves': 170, 'lgb_ff': 0.723289216780704, 'lgb_bf': 0.7229171215277066, 'lgb_freq': 1, 'lgb_alpha': 0.0007983396811300527, 'lgb_lambda': 0.0006320230592473134}. Best is trial 28 with value: 0.6492903077871958.
# [I 2025-07-24 17:09:36,440] Trial 38 finished with value: 0.6380832172781674 and parameters: {'model': 'lgbm', 'lgb_lr': 0.015097090772380008, 'lgb_est': 851, 'lgb_leaves': 56, 'lgb_ff': 0.9103627816481868, 'lgb_bf': 0.8686121779751008, 'lgb_freq': 2, 'lgb_alpha': 1.7731680461007648e-08, 'lgb_lambda': 0.023102973901107333}. Best is trial 28 with value: 0.6492903077871958.
# [I 2025-07-24 17:09:36,925] Trial 39 finished with value: 0.5422195004200713 and parameters: {'model': 'dt', 'dt_crit': 'entropy', 'dt_depth': 20, 'dt_split': 2, 'dt_leaf': 16}. Best is trial 28 with value: 0.6492903077871958.
# [I 2025-07-24 17:09:40,875] Trial 40 finished with value: 0.6470088326908485 and parameters: {'model': 'lgbm', 'lgb_lr': 0.036581209658020475, 'lgb_est': 105, 'lgb_leaves': 107, 'lgb_ff': 0.8375142552093795, 'lgb_bf': 0.5666033942808557, 'lgb_freq': 1, 'lgb_alpha': 0.9377220039600686, 'lgb_lambda': 0.7457438360651898}. Best is trial 28 with value: 0.6492903077871958.
# [I 2025-07-24 17:09:45,238] Trial 41 finished with value: 0.6406684221676696 and parameters: {'model': 'lgbm', 'lgb_lr': 0.0304189716018664, 'lgb_est': 119, 'lgb_leaves': 105, 'lgb_ff': 0.8408617026089323, 'lgb_bf': 0.5768837083622036, 'lgb_freq': 1, 'lgb_alpha': 0.8558942053792851, 'lgb_lambda': 1.1668301865122992}. Best is trial 28 with value: 0.6492903077871958.
# [I 2025-07-24 17:09:56,963] Trial 42 finished with value: 0.6492904390085987 and parameters: {'model': 'lgbm', 'lgb_lr': 0.066954198416256, 'lgb_est': 250, 'lgb_leaves': 111, 'lgb_ff': 0.9409680053431105, 'lgb_bf': 0.5653057718207538, 'lgb_freq': 0, 'lgb_alpha': 0.8223034525325068, 'lgb_lambda': 1.4004064153182945}. Best is trial 42 with value: 0.6492904390085987.
# [I 2025-07-24 17:10:08,380] Trial 43 finished with value: 0.6425436976140151 and parameters: {'model': 'lgbm', 'lgb_lr': 0.07276233984247409, 'lgb_est': 270, 'lgb_leaves': 141, 'lgb_ff': 0.7546243392049643, 'lgb_bf': 0.5579393135964137, 'lgb_freq': 0, 'lgb_alpha': 0.9614017530365726, 'lgb_lambda': 1.4881357081458038}. Best is trial 42 with value: 0.6492904390085987.
# [I 2025-07-24 17:10:18,933] Trial 44 finished with value: 0.6360369628095585 and parameters: {'model': 'lgbm', 'lgb_lr': 0.0847723771218029, 'lgb_est': 451, 'lgb_leaves': 173, 'lgb_ff': 0.8510309426722082, 'lgb_bf': 0.5527083750921599, 'lgb_freq': 0, 'lgb_alpha': 1.2158844494906553, 'lgb_lambda': 0.005114581352360932}. Best is trial 42 with value: 0.6492904390085987.
# [I 2025-07-24 17:10:19,351] Trial 45 finished with value: 0.4339541292526127 and parameters: {'model': 'dt', 'dt_crit': 'entropy', 'dt_depth': 2, 'dt_split': 9, 'dt_leaf': 1}. Best is trial 42 with value: 0.6492904390085987.
# [I 2025-07-24 17:10:33,876] Trial 46 finished with value: 0.6451652768119858 and parameters: {'model': 'lgbm', 'lgb_lr': 0.03523949998850903, 'lgb_est': 233, 'lgb_leaves': 116, 'lgb_ff': 0.940197774725138, 'lgb_bf': 0.5003224385801073, 'lgb_freq': 1, 'lgb_alpha': 0.00273708441131942, 'lgb_lambda': 3.859319235548318}. Best is trial 42 with value: 0.6492904390085987.
# [I 2025-07-24 17:10:38,463] Trial 47 finished with value: 0.5336256863377984 and parameters: {'model': 'rf', 'rf_estimators': 544, 'rf_depth': 30, 'rf_split': 13, 'rf_leaf': 20, 'rf_maxfeat': 'log2', 'rf_bootstrap': True}. Best is trial 42 with value: 0.6492904390085987.
# [I 2025-07-24 17:11:00,849] Trial 48 finished with value: 0.6446567851155437 and parameters: {'model': 'lgbm', 'lgb_lr': 0.06132060202038026, 'lgb_est': 325, 'lgb_leaves': 157, 'lgb_ff': 0.762449820410753, 'lgb_bf': 0.610599969656805, 'lgb_freq': 0, 'lgb_alpha': 0.3453307887123544, 'lgb_lambda': 0.3331866808018532}. Best is trial 42 with value: 0.6492904390085987.
# [I 2025-07-24 17:11:01,394] Trial 49 finished with value: 0.5335630692933442 and parameters: {'model': 'dt', 'dt_crit': 'entropy', 'dt_depth': 11, 'dt_split': 9, 'dt_leaf': 13}. Best is trial 42 with value: 0.6492904390085987.
# [I 2025-07-24 17:11:08,910] Trial 50 finished with value: 0.6504805004167822 and parameters: {'model': 'xgb', 'xgb_lr': 0.13025627493642303, 'xgb_est': 574, 'xgb_depth': 7, 'xgb_mc': 0.006104941713468388, 'xgb_sub': 0.8030216846904544, 'xgb_col': 0.788175997365597, 'xgb_gamma': 1.27537053689618, 'xgb_alpha': 0.07333664506141116, 'xgb_lambda': 8.160579476041455}. Best is trial 50 with value: 0.6504805004167822.
# [I 2025-07-24 17:11:17,015] Trial 51 finished with value: 0.6468116854416832 and parameters: {'model': 'xgb', 'xgb_lr': 0.13869066808751732, 'xgb_est': 665, 'xgb_depth': 7, 'xgb_mc': 0.006060785918326403, 'xgb_sub': 0.8005209992547783, 'xgb_col': 0.8166687083193238, 'xgb_gamma': 1.289189105258679, 'xgb_alpha': 0.12376805274033116, 'xgb_lambda': 7.581651915271293}. Best is trial 50 with value: 0.6504805004167822.
# [I 2025-07-24 17:11:23,240] Trial 52 finished with value: 0.6445364573539136 and parameters: {'model': 'xgb', 'xgb_lr': 0.1641808548599249, 'xgb_est': 512, 'xgb_depth': 7, 'xgb_mc': 0.0063058513772944755, 'xgb_sub': 0.7855321587291217, 'xgb_col': 0.6699251029864836, 'xgb_gamma': 1.802188774831339, 'xgb_alpha': 0.05815511175405334, 'xgb_lambda': 8.891874852661477}. Best is trial 50 with value: 0.6504805004167822.
# [I 2025-07-24 17:11:28,997] Trial 53 finished with value: 0.6403111497464028 and parameters: {'model': 'xgb', 'xgb_lr': 0.11389001549480335, 'xgb_est': 615, 'xgb_depth': 6, 'xgb_mc': 0.006814467159207536, 'xgb_sub': 0.6606313285441546, 'xgb_col': 0.7743315909963648, 'xgb_gamma': 1.1296512626285844, 'xgb_alpha': 0.00019945958216028244, 'xgb_lambda': 0.3212835994725952}. Best is trial 50 with value: 0.6504805004167822.
# [I 2025-07-24 17:11:31,990] Trial 54 finished with value: 0.6400406182952052 and parameters: {'model': 'xgb', 'xgb_lr': 0.10983969940189794, 'xgb_est': 395, 'xgb_depth': 8, 'xgb_mc': 0.06689255346686465, 'xgb_sub': 0.8686405941415253, 'xgb_col': 0.909401328286639, 'xgb_gamma': 1.9359833368994366, 'xgb_alpha': 0.000766592268058019, 'xgb_lambda': 0.01601490622255611}. Best is trial 50 with value: 0.6504805004167822.
# [I 2025-07-24 17:11:38,136] Trial 55 finished with value: 0.641645162295083 and parameters: {'model': 'xgb', 'xgb_lr': 0.19861261879457312, 'xgb_est': 976, 'xgb_depth': 5, 'xgb_mc': 0.0013702372818979202, 'xgb_sub': 0.7411582625968927, 'xgb_col': 0.7208418501490129, 'xgb_gamma': 0.9353253639192536, 'xgb_alpha': 0.02542469357631329, 'xgb_lambda': 7.868187634625597e-05}. Best is trial 50 with value: 0.6504805004167822.
# [I 2025-07-24 17:11:48,399] Trial 56 finished with value: 0.6359034385156246 and parameters: {'model': 'xgb', 'xgb_lr': 0.06910774466443576, 'xgb_est': 538, 'xgb_depth': 8, 'xgb_mc': 0.013298729951586331, 'xgb_sub': 0.6676058044521669, 'xgb_col': 0.6509731823021251, 'xgb_gamma': 0.06509931406290304, 'xgb_alpha': 4.737060479144306e-07, 'xgb_lambda': 0.06351127065391211}. Best is trial 50 with value: 0.6504805004167822.
# [I 2025-07-24 17:11:55,631] Trial 57 finished with value: 0.60720427397141 and parameters: {'model': 'rf', 'rf_estimators': 544, 'rf_depth': 19, 'rf_split': 12, 'rf_leaf': 10, 'rf_maxfeat': 'sqrt', 'rf_bootstrap': False}. Best is trial 50 with value: 0.6504805004167822.
# [I 2025-07-24 17:11:57,664] Trial 58 finished with value: 0.6334401886005389 and parameters: {'model': 'xgb', 'xgb_lr': 0.12895434661831068, 'xgb_est': 210, 'xgb_depth': 6, 'xgb_mc': 0.0029012397322632135, 'xgb_sub': 0.9472523144781242, 'xgb_col': 0.8294758236770378, 'xgb_gamma': 1.6807719067880535, 'xgb_alpha': 0.21868279567305457, 'xgb_lambda': 0.006070700721717492}. Best is trial 50 with value: 0.6504805004167822.
# [I 2025-07-24 17:12:08,053] Trial 59 finished with value: 0.6463589665268437 and parameters: {'model': 'lgbm', 'lgb_lr': 0.12066237902024572, 'lgb_est': 631, 'lgb_leaves': 194, 'lgb_ff': 0.9099751048932755, 'lgb_bf': 0.7229879605630476, 'lgb_freq': 1, 'lgb_alpha': 5.160353194895756, 'lgb_lambda': 6.746150536323154e-05}. Best is trial 50 with value: 0.6504805004167822.
# [I 2025-07-24 17:12:13,407] Trial 60 finished with value: 0.641313497021303 and parameters: {'model': 'xgb', 'xgb_lr': 0.09752120462137653, 'xgb_est': 725, 'xgb_depth': 7, 'xgb_mc': 0.09108351147185509, 'xgb_sub': 0.8325507199565191, 'xgb_col': 0.905125940104074, 'xgb_gamma': 0.849073650734974, 'xgb_alpha': 0.013918811053972522, 'xgb_lambda': 1.2283190335114964}. Best is trial 50 with value: 0.6504805004167822.
# [I 2025-07-24 17:12:17,478] Trial 61 finished with value: 0.6425977944514532 and parameters: {'model': 'xgb', 'xgb_lr': 0.14035552410355404, 'xgb_est': 642, 'xgb_depth': 7, 'xgb_mc': 0.005910450182859325, 'xgb_sub': 0.7890517580787728, 'xgb_col': 0.8135699626863062, 'xgb_gamma': 1.4081695610971643, 'xgb_alpha': 0.09047931483508433, 'xgb_lambda': 0.5448185001507155}. Best is trial 50 with value: 0.6504805004167822.
# [I 2025-07-24 17:12:21,975] Trial 62 finished with value: 0.6447959335082187 and parameters: {'model': 'xgb', 'xgb_lr': 0.15139621602462236, 'xgb_est': 735, 'xgb_depth': 8, 'xgb_mc': 0.013538884313600954, 'xgb_sub': 0.7136289896952792, 'xgb_col': 0.7973608966907583, 'xgb_gamma': 2.2845657805326542, 'xgb_alpha': 0.29824035401958937, 'xgb_lambda': 8.965468889163867}. Best is trial 50 with value: 0.6504805004167822.
# [I 2025-07-24 17:12:26,341] Trial 63 finished with value: 0.6366088342527614 and parameters: {'model': 'xgb', 'xgb_lr': 0.07149002567063344, 'xgb_est': 588, 'xgb_depth': 7, 'xgb_mc': 0.0029451803205106583, 'xgb_sub': 0.8200927728792421, 'xgb_col': 0.7318932957720227, 'xgb_gamma': 1.1046592526203791, 'xgb_alpha': 0.0015808876625291097, 'xgb_lambda': 3.54787133528257}. Best is trial 50 with value: 0.6504805004167822.
# [I 2025-07-24 17:12:29,928] Trial 64 finished with value: 0.6449046073928147 and parameters: {'model': 'xgb', 'xgb_lr': 0.12853595163637183, 'xgb_est': 488, 'xgb_depth': 6, 'xgb_mc': 0.0032525024602417236, 'xgb_sub': 0.7562033610514096, 'xgb_col': 0.8653963944157961, 'xgb_gamma': 0.6490224144017687, 'xgb_alpha': 2.7615653931859523, 'xgb_lambda': 0.07748200026182972}. Best is trial 50 with value: 0.6504805004167822.
# [I 2025-07-24 17:12:31,829] Trial 65 finished with value: 0.6490505073842561 and parameters: {'model': 'xgb', 'xgb_lr': 0.09175919935343556, 'xgb_est': 178, 'xgb_depth': 5, 'xgb_mc': 0.15924583755199812, 'xgb_sub': 0.6938557005322531, 'xgb_col': 0.6933930986127875, 'xgb_gamma': 1.5482458100080574, 'xgb_alpha': 0.04801588529308206, 'xgb_lambda': 1.734861942663667e-05}. Best is trial 50 with value: 0.6504805004167822.
# [I 2025-07-24 17:12:33,512] Trial 66 finished with value: 0.6465337653738017 and parameters: {'model': 'xgb', 'xgb_lr': 0.08562525409557738, 'xgb_est': 181, 'xgb_depth': 4, 'xgb_mc': 0.18552751841200704, 'xgb_sub': 0.642729432977044, 'xgb_col': 0.618283301836721, 'xgb_gamma': 2.9873246042740007, 'xgb_alpha': 0.009994094582111668, 'xgb_lambda': 1.7369576022744327e-05}. Best is trial 50 with value: 0.6504805004167822.
# [I 2025-07-24 17:12:41,267] Trial 67 finished with value: 0.6432690067733077 and parameters: {'model': 'lgbm', 'lgb_lr': 0.09401034931583538, 'lgb_est': 173, 'lgb_leaves': 53, 'lgb_ff': 0.8494912037376958, 'lgb_bf': 0.5407450862064017, 'lgb_freq': 0, 'lgb_alpha': 1.774021365003067, 'lgb_lambda': 0.002941275844734248}. Best is trial 50 with value: 0.6504805004167822.
# [I 2025-07-24 17:12:41,783] Trial 68 finished with value: 0.534749801641664 and parameters: {'model': 'dt', 'dt_crit': 'gini', 'dt_depth': 15, 'dt_split': 14, 'dt_leaf': 19}. Best is trial 50 with value: 0.6504805004167822.
# [I 2025-07-24 17:12:50,452] Trial 69 finished with value: 0.6031771899219145 and parameters: {'model': 'rf', 'rf_estimators': 713, 'rf_depth': 23, 'rf_split': 2, 'rf_leaf': 9, 'rf_maxfeat': 'sqrt', 'rf_bootstrap': True}. Best is trial 50 with value: 0.6504805004167822.
# [I 2025-07-24 17:12:52,418] Trial 70 finished with value: 0.6454263220438743 and parameters: {'model': 'xgb', 'xgb_lr': 0.09230090779537714, 'xgb_est': 182, 'xgb_depth': 5, 'xgb_mc': 0.471180936727077, 'xgb_sub': 0.6894567279536654, 'xgb_col': 0.6777889221831379, 'xgb_gamma': 2.1621821236305836, 'xgb_alpha': 0.033556563265858326, 'xgb_lambda': 2.922656805051694e-07}. Best is trial 50 with value: 0.6504805004167822.
# [I 2025-07-24 17:12:54,969] Trial 71 finished with value: 0.6501967108840113 and parameters: {'model': 'xgb', 'xgb_lr': 0.1656636027950637, 'xgb_est': 285, 'xgb_depth': 4, 'xgb_mc': 0.013152140105033997, 'xgb_sub': 0.7578228463367089, 'xgb_col': 0.698905360831959, 'xgb_gamma': 1.6160308380063015, 'xgb_alpha': 0.1851343402207795, 'xgb_lambda': 0.0005201762570242135}. Best is trial 50 with value: 0.6504805004167822.
# [I 2025-07-24 17:12:57,718] Trial 72 finished with value: 0.6430761262160678 and parameters: {'model': 'xgb', 'xgb_lr': 0.18383298806061177, 'xgb_est': 281, 'xgb_depth': 3, 'xgb_mc': 0.056026425442003966, 'xgb_sub': 0.7220415024182659, 'xgb_col': 0.6947331327592322, 'xgb_gamma': 1.494780240500365, 'xgb_alpha': 0.5075398816723659, 'xgb_lambda': 0.00022083497444467658}. Best is trial 50 with value: 0.6504805004167822.
# [I 2025-07-24 17:13:00,066] Trial 73 finished with value: 0.643106289293593 and parameters: {'model': 'xgb', 'xgb_lr': 0.1698006431131208, 'xgb_est': 245, 'xgb_depth': 4, 'xgb_mc': 0.021865322962661787, 'xgb_sub': 0.7638759007520978, 'xgb_col': 0.7514085508543648, 'xgb_gamma': 1.654550779925575, 'xgb_alpha': 1.305584626441257, 'xgb_lambda': 0.0007335734675258154}. Best is trial 50 with value: 0.6504805004167822.
# [I 2025-07-24 17:13:04,113] Trial 74 finished with value: 0.6397725527237436 and parameters: {'model': 'xgb', 'xgb_lr': 0.11150524288384378, 'xgb_est': 359, 'xgb_depth': 4, 'xgb_mc': 0.013457647644046014, 'xgb_sub': 0.6303156599194436, 'xgb_col': 0.6459255067167431, 'xgb_gamma': 0.3776801659349942, 'xgb_alpha': 0.004819526176348531, 'xgb_lambda': 0.003750723898575604}. Best is trial 50 with value: 0.6504805004167822.
# [I 2025-07-24 17:13:30,030] Trial 75 finished with value: 0.6425591920665447 and parameters: {'model': 'lgbm', 'lgb_lr': 0.06264455249939414, 'lgb_est': 586, 'lgb_leaves': 93, 'lgb_ff': 0.9676957245784238, 'lgb_bf': 0.6064082632041603, 'lgb_freq': 1, 'lgb_alpha': 0.0038894793303223896, 'lgb_lambda': 1.6571767355749862}. Best is trial 50 with value: 0.6504805004167822.
# [I 2025-07-24 17:13:32,034] Trial 76 finished with value: 0.6445192598378311 and parameters: {'model': 'xgb', 'xgb_lr': 0.07226340454336323, 'xgb_est': 161, 'xgb_depth': 3, 'xgb_mc': 0.03684092672473581, 'xgb_sub': 0.688393040828294, 'xgb_col': 0.6946750124813355, 'xgb_gamma': 2.0042730281613497, 'xgb_alpha': 0.2505816390196774, 'xgb_lambda': 5.499798945567189e-06}. Best is trial 50 with value: 0.6504805004167822.
# [I 2025-07-24 17:14:05,456] Trial 77 finished with value: 0.6435899100351089 and parameters: {'model': 'lgbm', 'lgb_lr': 0.19139513821259552, 'lgb_est': 875, 'lgb_leaves': 127, 'lgb_ff': 0.8770405751730612, 'lgb_bf': 0.5321809567314686, 'lgb_freq': 3, 'lgb_alpha': 4.095205626500456e-05, 'lgb_lambda': 0.22791592662440618}. Best is trial 50 with value: 0.6504805004167822.
# [I 2025-07-24 17:14:09,436] Trial 78 finished with value: 0.657256283774744 and parameters: {'model': 'xgb', 'xgb_lr': 0.05946300117061984, 'xgb_est': 330, 'xgb_depth': 5, 'xgb_mc': 0.17268980636500436, 'xgb_sub': 0.5615472270531047, 'xgb_col': 0.6190407860008285, 'xgb_gamma': 1.0183211137412185, 'xgb_alpha': 0.04335998689290226, 'xgb_lambda': 0.0011702340484567484}. Best is trial 78 with value: 0.657256283774744.
# [I 2025-07-24 17:14:13,249] Trial 79 finished with value: 0.6412489505017342 and parameters: {'model': 'xgb', 'xgb_lr': 0.05630787745128459, 'xgb_est': 330, 'xgb_depth': 5, 'xgb_mc': 0.1524665446115052, 'xgb_sub': 0.7222540272858835, 'xgb_col': 0.6053638756735633, 'xgb_gamma': 1.0215680141483026, 'xgb_alpha': 0.03350579806651601, 'xgb_lambda': 0.0010230254008047317}. Best is trial 78 with value: 0.657256283774744.
# [I 2025-07-24 17:14:17,065] Trial 80 finished with value: 0.653652032396098 and parameters: {'model': 'xgb', 'xgb_lr': 0.04131909967965247, 'xgb_est': 223, 'xgb_depth': 6, 'xgb_mc': 0.1345154398973546, 'xgb_sub': 0.5632073938952565, 'xgb_col': 0.5460188210822589, 'xgb_gamma': 0.6691182178482394, 'xgb_alpha': 1.4853740730152836, 'xgb_lambda': 6.67646363276263e-05}. Best is trial 78 with value: 0.657256283774744.
# [I 2025-07-24 17:14:21,605] Trial 81 finished with value: 0.6516640913525846 and parameters: {'model': 'xgb', 'xgb_lr': 0.03077356818649905, 'xgb_est': 249, 'xgb_depth': 6, 'xgb_mc': 0.11428465208950633, 'xgb_sub': 0.5746206879806515, 'xgb_col': 0.5499851740298523, 'xgb_gamma': 0.5949152280532197, 'xgb_alpha': 1.6529168634199312, 'xgb_lambda': 7.085366783166513e-05}. Best is trial 78 with value: 0.657256283774744.
# [I 2025-07-24 17:14:25,780] Trial 82 finished with value: 0.6482080101497053 and parameters: {'model': 'xgb', 'xgb_lr': 0.03277499291888455, 'xgb_est': 233, 'xgb_depth': 6, 'xgb_mc': 0.1298471587666966, 'xgb_sub': 0.5425478712474884, 'xgb_col': 0.5366919328432967, 'xgb_gamma': 0.5952515727623668, 'xgb_alpha': 1.208356493097804, 'xgb_lambda': 6.9540787553584e-05}. Best is trial 78 with value: 0.657256283774744.
# [I 2025-07-24 17:14:28,689] Trial 83 finished with value: 0.6497166049271483 and parameters: {'model': 'xgb', 'xgb_lr': 0.03953044444830363, 'xgb_est': 160, 'xgb_depth': 5, 'xgb_mc': 0.24620411269246786, 'xgb_sub': 0.5814328151283011, 'xgb_col': 0.5361630273551313, 'xgb_gamma': 0.2620131423386931, 'xgb_alpha': 1.9404521753332995, 'xgb_lambda': 1.899469226559004e-05}. Best is trial 78 with value: 0.657256283774744.
# [I 2025-07-24 17:14:31,308] Trial 84 finished with value: 0.654064400507726 and parameters: {'model': 'xgb', 'xgb_lr': 0.03939291677688078, 'xgb_est': 146, 'xgb_depth': 5, 'xgb_mc': 0.2510766290706113, 'xgb_sub': 0.5714358675898051, 'xgb_col': 0.5451594651938994, 'xgb_gamma': 0.2522916425460935, 'xgb_alpha': 2.6890289208081968, 'xgb_lambda': 8.642321111032795e-06}. Best is trial 78 with value: 0.657256283774744.
# [I 2025-07-24 17:14:33,750] Trial 85 finished with value: 0.6472908589422988 and parameters: {'model': 'xgb', 'xgb_lr': 0.036932642844105114, 'xgb_est': 153, 'xgb_depth': 4, 'xgb_mc': 0.3550130293901368, 'xgb_sub': 0.5637136837897003, 'xgb_col': 0.5407027592869017, 'xgb_gamma': 0.33056894252531727, 'xgb_alpha': 2.8255945600116887, 'xgb_lambda': 2.630592796720581e-06}. Best is trial 78 with value: 0.657256283774744.
# [I 2025-07-24 17:14:35,943] Trial 86 finished with value: 0.6259022312198116 and parameters: {'model': 'xgb', 'xgb_lr': 0.0250990185240178, 'xgb_est': 135, 'xgb_depth': 5, 'xgb_mc': 0.28679867016098237, 'xgb_sub': 0.5663998027808177, 'xgb_col': 0.5416436624243067, 'xgb_gamma': 0.2192795984510399, 'xgb_alpha': 8.449447117123942, 'xgb_lambda': 6.138452310165428e-07}. Best is trial 78 with value: 0.657256283774744.
# [I 2025-07-24 17:14:41,548] Trial 87 finished with value: 0.6520283701055952 and parameters: {'model': 'xgb', 'xgb_lr': 0.04362002667522671, 'xgb_est': 409, 'xgb_depth': 6, 'xgb_mc': 0.529980525819554, 'xgb_sub': 0.5348598007395304, 'xgb_col': 0.5837345622129027, 'xgb_gamma': 0.5570929748985293, 'xgb_alpha': 2.1830497967890405, 'xgb_lambda': 1.4715236662725855e-05}. Best is trial 78 with value: 0.657256283774744.
# [I 2025-07-24 17:14:47,341] Trial 88 finished with value: 0.6480339418457415 and parameters: {'model': 'xgb', 'xgb_lr': 0.04147846551689158, 'xgb_est': 426, 'xgb_depth': 6, 'xgb_mc': 0.6423791820652834, 'xgb_sub': 0.5331814540911058, 'xgb_col': 0.5841608695892166, 'xgb_gamma': 0.5700871309745978, 'xgb_alpha': 1.9958856985427482, 'xgb_lambda': 1.20767067978554e-05}. Best is trial 78 with value: 0.657256283774744.
# [I 2025-07-24 17:14:52,955] Trial 89 finished with value: 0.6510641646733841 and parameters: {'model': 'xgb', 'xgb_lr': 0.025279409501193277, 'xgb_est': 280, 'xgb_depth': 6, 'xgb_mc': 0.24360139624948082, 'xgb_sub': 0.5010099115233698, 'xgb_col': 0.5547078255086121, 'xgb_gamma': 0.20122170470587245, 'xgb_alpha': 0.6778507237129853, 'xgb_lambda': 5.854446868683632e-05}. Best is trial 78 with value: 0.657256283774744.
# [I 2025-07-24 17:14:58,468] Trial 90 finished with value: 0.6545707912361822 and parameters: {'model': 'xgb', 'xgb_lr': 0.025113661712806677, 'xgb_est': 270, 'xgb_depth': 6, 'xgb_mc': 0.22258680544087225, 'xgb_sub': 0.5075102445362624, 'xgb_col': 0.555944682674212, 'xgb_gamma': 0.22685743087390337, 'xgb_alpha': 0.8482799148965314, 'xgb_lambda': 7.965492921469649e-05}. Best is trial 78 with value: 0.657256283774744.
# [I 2025-07-24 17:15:04,128] Trial 91 finished with value: 0.6434703536818414 and parameters: {'model': 'xgb', 'xgb_lr': 0.024079254715156692, 'xgb_est': 286, 'xgb_depth': 6, 'xgb_mc': 0.2534772584133773, 'xgb_sub': 0.5078225471707304, 'xgb_col': 0.5567171073616721, 'xgb_gamma': 0.17202888321788354, 'xgb_alpha': 0.7144115259646832, 'xgb_lambda': 6.499012092114837e-05}. Best is trial 78 with value: 0.657256283774744.
# [I 2025-07-24 17:15:09,148] Trial 92 finished with value: 0.6483533906550242 and parameters: {'model': 'xgb', 'xgb_lr': 0.025771673844317465, 'xgb_est': 319, 'xgb_depth': 6, 'xgb_mc': 0.5239258633291632, 'xgb_sub': 0.5462053107865993, 'xgb_col': 0.5278035178524787, 'xgb_gamma': 0.36705379813824035, 'xgb_alpha': 3.56986689500831, 'xgb_lambda': 3.532206080011668e-05}. Best is trial 78 with value: 0.657256283774744.
# [I 2025-07-24 17:15:13,212] Trial 93 finished with value: 0.6478984424214462 and parameters: {'model': 'xgb', 'xgb_lr': 0.035608584775554473, 'xgb_est': 262, 'xgb_depth': 5, 'xgb_mc': 0.09885426200310553, 'xgb_sub': 0.5922981150765598, 'xgb_col': 0.563323685343251, 'xgb_gamma': 0.6944015353976625, 'xgb_alpha': 0.6302744431365294, 'xgb_lambda': 0.00032511241372170296}. Best is trial 78 with value: 0.657256283774744.
# [I 2025-07-24 17:15:19,004] Trial 94 finished with value: 0.6481892010216512 and parameters: {'model': 'xgb', 'xgb_lr': 0.018914266474208984, 'xgb_est': 365, 'xgb_depth': 5, 'xgb_mc': 0.25313481081936084, 'xgb_sub': 0.5177802256460793, 'xgb_col': 0.5886271379670708, 'xgb_gamma': 0.4477510472926979, 'xgb_alpha': 1.294473358486527, 'xgb_lambda': 0.00014498696842545894}. Best is trial 78 with value: 0.657256283774744.
# [I 2025-07-24 17:15:22,137] Trial 95 finished with value: 0.6507100797110738 and parameters: {'model': 'xgb', 'xgb_lr': 0.04684523836923902, 'xgb_est': 219, 'xgb_depth': 6, 'xgb_mc': 0.8157909617675072, 'xgb_sub': 0.5691461730141181, 'xgb_col': 0.5199670898631709, 'xgb_gamma': 0.2011363961483252, 'xgb_alpha': 9.857032970537787, 'xgb_lambda': 4.758147823457481e-06}. Best is trial 78 with value: 0.657256283774744.
# [I 2025-07-24 17:15:25,055] Trial 96 finished with value: 0.6489314880206565 and parameters: {'model': 'xgb', 'xgb_lr': 0.05164710177379971, 'xgb_est': 230, 'xgb_depth': 6, 'xgb_mc': 1.3699314373195821, 'xgb_sub': 0.5537681296761312, 'xgb_col': 0.5196445862907578, 'xgb_gamma': 0.5276139879792672, 'xgb_alpha': 9.720843490804597, 'xgb_lambda': 4.900773517205225e-06}. Best is trial 78 with value: 0.657256283774744.
# [I 2025-07-24 17:15:29,721] Trial 97 finished with value: 0.6461424359623587 and parameters: {'model': 'xgb', 'xgb_lr': 0.04571868829524727, 'xgb_est': 287, 'xgb_depth': 6, 'xgb_mc': 0.6754351242415576, 'xgb_sub': 0.5217487499397706, 'xgb_col': 0.5583535965460871, 'xgb_gamma': 0.02357266248131981, 'xgb_alpha': 5.235038156652724, 'xgb_lambda': 1.5015627663004663e-06}. Best is trial 78 with value: 0.657256283774744.
# [I 2025-07-24 17:15:35,199] Trial 98 finished with value: 0.6496898362960046 and parameters: {'model': 'xgb', 'xgb_lr': 0.02759016695554862, 'xgb_est': 330, 'xgb_depth': 6, 'xgb_mc': 0.11915031828257032, 'xgb_sub': 0.5731055801972561, 'xgb_col': 0.6242910470041273, 'xgb_gamma': 0.7483693928852003, 'xgb_alpha': 0.5662432969829231, 'xgb_lambda': 0.0005335952620612773}. Best is trial 78 with value: 0.657256283774744.
# [I 2025-07-24 17:15:38,830] Trial 99 finished with value: 0.6385142825818925 and parameters: {'model': 'xgb', 'xgb_lr': 0.020820529605227667, 'xgb_est': 265, 'xgb_depth': 6, 'xgb_mc': 0.9044024201381419, 'xgb_sub': 0.5008721207196507, 'xgb_col': 0.5021362252993313, 'xgb_gamma': 0.9560433826833261, 'xgb_alpha': 5.2335973220732175, 'xgb_lambda': 3.9154000570968394e-05}. Best is trial 78 with value: 0.657256283774744.
# [I 2025-07-24 17:15:47,136] Trial 100 finished with value: 0.653124078502951 and parameters: {'model': 'xgb', 'xgb_lr': 0.030843406919545846, 'xgb_est': 392, 'xgb_depth': 7, 'xgb_mc': 0.40020879613843424, 'xgb_sub': 0.5318190031187229, 'xgb_col': 0.5920641123827252, 'xgb_gamma': 0.14134082345990823, 'xgb_alpha': 0.3429449025430187, 'xgb_lambda': 0.00013458271564599362}. Best is trial 78 with value: 0.657256283774744.
# [I 2025-07-24 17:15:56,314] Trial 101 finished with value: 0.6518392874760236 and parameters: {'model': 'xgb', 'xgb_lr': 0.029494817505513683, 'xgb_est': 372, 'xgb_depth': 7, 'xgb_mc': 0.19539877919328005, 'xgb_sub': 0.5400988342477191, 'xgb_col': 0.5753359394735622, 'xgb_gamma': 0.0038478988645603285, 'xgb_alpha': 0.33231340211549754, 'xgb_lambda': 0.00013048247975958063}. Best is trial 78 with value: 0.657256283774744.
# [I 2025-07-24 17:16:05,533] Trial 102 finished with value: 0.6519101491961498 and parameters: {'model': 'xgb', 'xgb_lr': 0.0320880049716542, 'xgb_est': 401, 'xgb_depth': 7, 'xgb_mc': 0.3843538391212576, 'xgb_sub': 0.5338065675469086, 'xgb_col': 0.5734086332019454, 'xgb_gamma': 0.004282792030799121, 'xgb_alpha': 0.9607958161395981, 'xgb_lambda': 0.00012455621965320093}. Best is trial 78 with value: 0.657256283774744.
# [I 2025-07-24 17:16:15,118] Trial 103 finished with value: 0.6448595396459583 and parameters: {'model': 'xgb', 'xgb_lr': 0.03030202216101035, 'xgb_est': 415, 'xgb_depth': 7, 'xgb_mc': 0.3763067140437026, 'xgb_sub': 0.5309644967941508, 'xgb_col': 0.5776530056167539, 'xgb_gamma': 0.004780537655183575, 'xgb_alpha': 0.9523732348438383, 'xgb_lambda': 0.0001210960359601102}. Best is trial 78 with value: 0.657256283774744.
# [I 2025-07-24 17:16:23,096] Trial 104 finished with value: 0.6518952891662594 and parameters: {'model': 'xgb', 'xgb_lr': 0.033274327212464254, 'xgb_est': 463, 'xgb_depth': 7, 'xgb_mc': 0.19062463292041756, 'xgb_sub': 0.610883912912791, 'xgb_col': 0.6017125119533092, 'xgb_gamma': 0.15621500659805526, 'xgb_alpha': 2.572221246115248, 'xgb_lambda': 4.8015601978144795e-05}. Best is trial 78 with value: 0.657256283774744.
# [I 2025-07-24 17:16:31,972] Trial 105 finished with value: 0.6456745359845447 and parameters: {'model': 'xgb', 'xgb_lr': 0.03461144527069397, 'xgb_est': 462, 'xgb_depth': 7, 'xgb_mc': 0.2012235880857652, 'xgb_sub': 0.6067124653968645, 'xgb_col': 0.6020369841210061, 'xgb_gamma': 0.1389696177013681, 'xgb_alpha': 0.3608419239868598, 'xgb_lambda': 0.00013373430401512632}. Best is trial 78 with value: 0.657256283774744.
# [I 2025-07-24 17:16:38,935] Trial 106 finished with value: 0.6524808223525335 and parameters: {'model': 'xgb', 'xgb_lr': 0.022491568122948315, 'xgb_est': 373, 'xgb_depth': 8, 'xgb_mc': 0.389262766660386, 'xgb_sub': 0.5515683471445785, 'xgb_col': 0.5542368861029842, 'xgb_gamma': 0.4600985656669098, 'xgb_alpha': 2.2594869919294425, 'xgb_lambda': 3.409212154534241e-05}. Best is trial 78 with value: 0.657256283774744.
# [I 2025-07-24 17:16:39,356] Trial 107 finished with value: 0.5422955836327462 and parameters: {'model': 'dt', 'dt_crit': 'gini', 'dt_depth': 7, 'dt_split': 6, 'dt_leaf': 11}. Best is trial 78 with value: 0.657256283774744.
# [I 2025-07-24 17:16:46,367] Trial 108 finished with value: 0.6571793177909031 and parameters: {'model': 'xgb', 'xgb_lr': 0.02947219758072011, 'xgb_est': 394, 'xgb_depth': 8, 'xgb_mc': 0.396564245951146, 'xgb_sub': 0.5518991088781364, 'xgb_col': 0.5923042375868994, 'xgb_gamma': 0.41747759662669004, 'xgb_alpha': 1.9254334562806161, 'xgb_lambda': 2.9826523715366313e-05}. Best is trial 78 with value: 0.657256283774744.
# [I 2025-07-24 17:17:16,800] Trial 109 finished with value: 0.5408025301693999 and parameters: {'model': 'rf', 'rf_estimators': 323, 'rf_depth': 11, 'rf_split': 8, 'rf_leaf': 15, 'rf_maxfeat': None, 'rf_bootstrap': False}. Best is trial 78 with value: 0.657256283774744.
# [I 2025-07-24 17:17:23,862] Trial 110 finished with value: 0.6502817330179642 and parameters: {'model': 'xgb', 'xgb_lr': 0.021090270758264723, 'xgb_est': 396, 'xgb_depth': 8, 'xgb_mc': 0.4072069106625611, 'xgb_sub': 0.5482577338209944, 'xgb_col': 0.5945748849148551, 'xgb_gamma': 0.4304558426216213, 'xgb_alpha': 3.504985701768491, 'xgb_lambda': 2.9399620378724687e-05}. Best is trial 78 with value: 0.657256283774744.
# [I 2025-07-24 17:17:30,566] Trial 111 finished with value: 0.6483070840359516 and parameters: {'model': 'xgb', 'xgb_lr': 0.029186932244340217, 'xgb_est': 382, 'xgb_depth': 8, 'xgb_mc': 0.07576858124746932, 'xgb_sub': 0.5878141107245641, 'xgb_col': 0.6293673790917484, 'xgb_gamma': 0.48473738399367, 'xgb_alpha': 2.1917300216834077, 'xgb_lambda': 1.007760618800544e-05}. Best is trial 78 with value: 0.657256283774744.
# [I 2025-07-24 17:17:38,788] Trial 112 finished with value: 0.6502852660134473 and parameters: {'model': 'xgb', 'xgb_lr': 0.03299193182223788, 'xgb_est': 448, 'xgb_depth': 9, 'xgb_mc': 0.3173464355043929, 'xgb_sub': 0.5289240223804531, 'xgb_col': 0.5733317469087944, 'xgb_gamma': 0.28918136215599555, 'xgb_alpha': 1.4253173293435835, 'xgb_lambda': 0.0002392696441796698}. Best is trial 78 with value: 0.657256283774744.
# [I 2025-07-24 17:17:43,639] Trial 113 finished with value: 0.6523398952719157 and parameters: {'model': 'xgb', 'xgb_lr': 0.03841291410686758, 'xgb_est': 348, 'xgb_depth': 8, 'xgb_mc': 0.5421504165491213, 'xgb_sub': 0.5536444535426156, 'xgb_col': 0.575070508701768, 'xgb_gamma': 0.7216672971825425, 'xgb_alpha': 2.9984722072180823, 'xgb_lambda': 9.210651056198267e-05}. Best is trial 78 with value: 0.657256283774744.
# [I 2025-07-24 17:17:51,225] Trial 114 finished with value: 0.6522008993179081 and parameters: {'model': 'xgb', 'xgb_lr': 0.0390474775631131, 'xgb_est': 407, 'xgb_depth': 8, 'xgb_mc': 0.5234865363681123, 'xgb_sub': 0.554620750208564, 'xgb_col': 0.5733265471944046, 'xgb_gamma': 0.01091411271978035, 'xgb_alpha': 3.9784720523457504, 'xgb_lambda': 2.785014456287376e-05}. Best is trial 78 with value: 0.657256283774744.
# [I 2025-07-24 17:17:56,586] Trial 115 finished with value: 0.6541122577633267 and parameters: {'model': 'xgb', 'xgb_lr': 0.038682865247355, 'xgb_est': 405, 'xgb_depth': 8, 'xgb_mc': 0.5336949267681728, 'xgb_sub': 0.5565198018206139, 'xgb_col': 0.5922307680292591, 'xgb_gamma': 0.7862001429683303, 'xgb_alpha': 4.631908264479577, 'xgb_lambda': 2.489734483513363e-05}. Best is trial 78 with value: 0.657256283774744.
# [I 2025-07-24 17:18:01,618] Trial 116 finished with value: 0.6525114813842697 and parameters: {'model': 'xgb', 'xgb_lr': 0.03969592575908445, 'xgb_est': 409, 'xgb_depth': 8, 'xgb_mc': 0.5624634623326421, 'xgb_sub': 0.5562018336543116, 'xgb_col': 0.5867808144481355, 'xgb_gamma': 0.8062334842214245, 'xgb_alpha': 4.203814009263574, 'xgb_lambda': 2.165746333701892e-05}. Best is trial 78 with value: 0.657256283774744.
# [I 2025-07-24 17:18:06,722] Trial 117 finished with value: 0.6508311776739317 and parameters: {'model': 'xgb', 'xgb_lr': 0.03843506322408735, 'xgb_est': 422, 'xgb_depth': 8, 'xgb_mc': 0.5942354182115342, 'xgb_sub': 0.5613618622898315, 'xgb_col': 0.5892719796112232, 'xgb_gamma': 0.7283147970837169, 'xgb_alpha': 4.933938961295533, 'xgb_lambda': 2.5504966331833334e-05}. Best is trial 78 with value: 0.657256283774744.
# [I 2025-07-24 17:18:11,415] Trial 118 finished with value: 0.6548816566873568 and parameters: {'model': 'xgb', 'xgb_lr': 0.042922239422542995, 'xgb_est': 340, 'xgb_depth': 9, 'xgb_mc': 1.2012474238914697, 'xgb_sub': 0.5554226076117726, 'xgb_col': 0.6130774726745509, 'xgb_gamma': 0.8551074207013385, 'xgb_alpha': 4.275724234425343, 'xgb_lambda': 9.86940490428976e-06}. Best is trial 78 with value: 0.657256283774744.
# [I 2025-07-24 17:18:15,477] Trial 119 finished with value: 0.6567934254942015 and parameters: {'model': 'xgb', 'xgb_lr': 0.05106532884726325, 'xgb_est': 348, 'xgb_depth': 10, 'xgb_mc': 1.3250153017916393, 'xgb_sub': 0.5549350144152426, 'xgb_col': 0.6162480481962902, 'xgb_gamma': 0.7343621431023212, 'xgb_alpha': 4.931758631854122, 'xgb_lambda': 9.22091468949528e-06}. Best is trial 78 with value: 0.657256283774744.
# [I 2025-07-24 17:18:20,095] Trial 120 finished with value: 0.6515799865106062 and parameters: {'model': 'xgb', 'xgb_lr': 0.052698581630573366, 'xgb_est': 347, 'xgb_depth': 10, 'xgb_mc': 3.7000338194928966, 'xgb_sub': 0.5168528689452437, 'xgb_col': 0.6330706858669125, 'xgb_gamma': 0.8310914942139802, 'xgb_alpha': 7.802366482182784e-06, 'xgb_lambda': 8.17088048688626e-06}. Best is trial 78 with value: 0.657256283774744.
# [I 2025-07-24 17:18:23,712] Trial 121 finished with value: 0.6519555290019073 and parameters: {'model': 'xgb', 'xgb_lr': 0.061575809260487724, 'xgb_est': 315, 'xgb_depth': 10, 'xgb_mc': 1.2343122990287594, 'xgb_sub': 0.5546800951287116, 'xgb_col': 0.620794959915206, 'xgb_gamma': 0.8883492297023566, 'xgb_alpha': 4.94623197807249, 'xgb_lambda': 2.5239276673476327e-06}. Best is trial 78 with value: 0.657256283774744.
# [I 2025-07-24 17:18:27,931] Trial 122 finished with value: 0.651139565981677 and parameters: {'model': 'xgb', 'xgb_lr': 0.042039811054134166, 'xgb_est': 338, 'xgb_depth': 9, 'xgb_mc': 2.444763754611258, 'xgb_sub': 0.5933444650910498, 'xgb_col': 0.6107998692223504, 'xgb_gamma': 1.0695716377118645, 'xgb_alpha': 3.8729987620387942, 'xgb_lambda': 2.8736950132203397e-05}. Best is trial 78 with value: 0.657256283774744.
# [I 2025-07-24 17:18:32,187] Trial 123 finished with value: 0.6488748042426403 and parameters: {'model': 'xgb', 'xgb_lr': 0.04868836091066272, 'xgb_est': 373, 'xgb_depth': 8, 'xgb_mc': 1.9506296517391255, 'xgb_sub': 0.5509059681087659, 'xgb_col': 0.5964481867718444, 'xgb_gamma': 0.6702685680149723, 'xgb_alpha': 6.176668266363253, 'xgb_lambda': 8.558520141842032e-06}. Best is trial 78 with value: 0.657256283774744.
# ...
# [I 2025-07-24 17:21:24,381] Trial 162 finished with value: 0.6532657339932764 and parameters: {'model': 'xgb', 'xgb_lr': 0.03324211102779212, 'xgb_est': 354, 'xgb_depth': 8, 'xgb_mc': 1.0583791894137737, 'xgb_sub': 0.5459866125877131, 'xgb_col': 0.5454476627136292, 'xgb_gamma': 1.1138198779925896, 'xgb_alpha': 0.06913916616762658, 'xgb_lambda': 1.3293854934326768e-06}. Best is trial 78 with value: 0.657256283774744.
# [I 2025-07-24 17:21:31,259] Trial 163 finished with value: 0.6542661286026485 and parameters: {'model': 'xgb', 'xgb_lr': 0.03393613726251561, 'xgb_est': 879, 'xgb_depth': 8, 'xgb_mc': 0.9345131462179089, 'xgb_sub': 0.544521934110261, 'xgb_col': 0.6125871841535157, 'xgb_gamma': 1.0751768525709158, 'xgb_alpha': 0.0713991082819448, 'xgb_lambda': 1.391059395213257e-06}. Best is trial 78 with value: 0.657256283774744.
# [I 2025-07-24 17:21:35,222] Trial 164 finished with value: 0.6464719261037909 and parameters: {'model': 'xgb', 'xgb_lr': 0.03357858509602862, 'xgb_est': 345, 'xgb_depth': 8, 'xgb_mc': 1.0731598862220455, 'xgb_sub': 0.5476468307063718, 'xgb_col': 0.6157792340438916, 'xgb_gamma': 1.1450744491258613, 'xgb_alpha': 0.05503365455478229, 'xgb_lambda': 1.3688878871770963e-06}. Best is trial 78 with value: 0.657256283774744.
# [I 2025-07-24 17:21:36,862] Trial 165 finished with value: 0.6457765473861107 and parameters: {'model': 'xgb', 'xgb_lr': 0.03127168899060123, 'xgb_est': 100, 'xgb_depth': 5, 'xgb_mc': 1.9147482028937128, 'xgb_sub': 0.5103504745406062, 'xgb_col': 0.5939924595453937, 'xgb_gamma': 0.9703962742583507, 'xgb_alpha': 0.0813426658292718, 'xgb_lambda': 4.457261600713831e-07}. Best is trial 78 with value: 0.657256283774744.
# [I 2025-07-24 17:21:41,531] Trial 166 finished with value: 0.6515264004469772 and parameters: {'model': 'xgb', 'xgb_lr': 0.037746406000446854, 'xgb_est': 361, 'xgb_depth': 7, 'xgb_mc': 1.310137200418049, 'xgb_sub': 0.5377744210311968, 'xgb_col': 0.5450215639906855, 'xgb_gamma': 0.5340009393869696, 'xgb_alpha': 0.7317742200108671, 'xgb_lambda': 0.00020654009447750027}. Best is trial 78 with value: 0.657256283774744.
# [I 2025-07-24 17:21:49,773] Trial 167 finished with value: 0.6450131684529781 and parameters: {'model': 'xgb', 'xgb_lr': 0.03283793062546023, 'xgb_est': 841, 'xgb_depth': 8, 'xgb_mc': 0.13346905086956934, 'xgb_sub': 0.5232312141759374, 'xgb_col': 0.5819154862672283, 'xgb_gamma': 0.37987132188966183, 'xgb_alpha': 8.856676050250992e-07, 'xgb_lambda': 2.520265101381827e-07}. Best is trial 78 with value: 0.657256283774744.
# [I 2025-07-24 17:21:57,914] Trial 168 finished with value: 0.6474081202424656 and parameters: {'model': 'xgb', 'xgb_lr': 0.029332411323614256, 'xgb_est': 992, 'xgb_depth': 12, 'xgb_mc': 0.9366177000055639, 'xgb_sub': 0.5475902734902043, 'xgb_col': 0.6087859123547941, 'xgb_gamma': 0.9012810060366232, 'xgb_alpha': 0.09066434390276379, 'xgb_lambda': 1.2493605095230895e-05}. Best is trial 78 with value: 0.657256283774744.
# [I 2025-07-24 17:22:03,219] Trial 169 finished with value: 0.6494083132132122 and parameters: {'model': 'xgb', 'xgb_lr': 0.05447834131000785, 'xgb_est': 689, 'xgb_depth': 8, 'xgb_mc': 0.22731116854820327, 'xgb_sub': 0.5593335404092756, 'xgb_col': 0.5614496637203801, 'xgb_gamma': 1.0683485292266512, 'xgb_alpha': 1.5002584218484942, 'xgb_lambda': 1.6714407492934824e-06}. Best is trial 78 with value: 0.657256283774744.
# [I 2025-07-24 17:22:06,905] Trial 170 finished with value: 0.644171055972129 and parameters: {'model': 'xgb', 'xgb_lr': 0.039996896021990164, 'xgb_est': 254, 'xgb_depth': 7, 'xgb_mc': 2.6052571859257156, 'xgb_sub': 0.5930328177714296, 'xgb_col': 0.6300974629204023, 'xgb_gamma': 0.6521882054265556, 'xgb_alpha': 0.016310107573876048, 'xgb_lambda': 8.800868371150268e-05}. Best is trial 78 with value: 0.657256283774744.
# [I 2025-07-24 17:22:10,765] Trial 171 finished with value: 0.6569389013379648 and parameters: {'model': 'xgb', 'xgb_lr': 0.03622829842901436, 'xgb_est': 339, 'xgb_depth': 8, 'xgb_mc': 0.6394271801055103, 'xgb_sub': 0.5617465449976116, 'xgb_col': 0.6589397097147337, 'xgb_gamma': 1.2487394267055458, 'xgb_alpha': 0.0015336709582029133, 'xgb_lambda': 7.159639141601528e-07}. Best is trial 78 with value: 0.657256283774744.
# [I 2025-07-24 17:22:16,381] Trial 172 finished with value: 0.65451009991747 and parameters: {'model': 'xgb', 'xgb_lr': 0.034764407124329745, 'xgb_est': 832, 'xgb_depth': 8, 'xgb_mc': 0.4832980335364223, 'xgb_sub': 0.5678349648236964, 'xgb_col': 0.5941017272172362, 'xgb_gamma': 2.743693838533596, 'xgb_alpha': 0.036087524007429386, 'xgb_lambda': 3.0029214536356303e-06}. Best is trial 78 with value: 0.657256283774744.
# [I 2025-07-24 17:22:22,297] Trial 173 finished with value: 0.6495057309335033 and parameters: {'model': 'xgb', 'xgb_lr': 0.03583541719599482, 'xgb_est': 877, 'xgb_depth': 8, 'xgb_mc': 0.49268705184659844, 'xgb_sub': 0.5340849606251565, 'xgb_col': 0.661977333938326, 'xgb_gamma': 2.7341718705184435, 'xgb_alpha': 0.023728059607118393, 'xgb_lambda': 2.531971682217473e-06}. Best is trial 78 with value: 0.657256283774744.
# [I 2025-07-24 17:22:25,385] Trial 174 finished with value: 0.6432885904708122 and parameters: {'model': 'xgb', 'xgb_lr': 0.034429548225354295, 'xgb_est': 345, 'xgb_depth': 9, 'xgb_mc': 0.2856666776569133, 'xgb_sub': 0.5687085973023197, 'xgb_col': 0.6837023640868723, 'xgb_gamma': 2.8527147086030484, 'xgb_alpha': 0.0328757113319158, 'xgb_lambda': 6.9169056184402975e-06}. Best is trial 78 with value: 0.657256283774744.
# [I 2025-07-24 17:22:31,476] Trial 175 finished with value: 0.6564019575943064 and parameters: {'model': 'xgb', 'xgb_lr': 0.030846533563649123, 'xgb_est': 922, 'xgb_depth': 5, 'xgb_mc': 0.3793015873859442, 'xgb_sub': 0.5512539729355594, 'xgb_col': 0.593689977935163, 'xgb_gamma': 2.493294824463659, 'xgb_alpha': 0.0012647194107913659, 'xgb_lambda': 0.00043096592034384877}. Best is trial 78 with value: 0.657256283774744.
# [I 2025-07-24 17:22:37,079] Trial 176 finished with value: 0.6199119871283311 and parameters: {'model': 'xgb', 'xgb_lr': 0.026763049592486453, 'xgb_est': 911, 'xgb_depth': 5, 'xgb_mc': 0.34788593637080095, 'xgb_sub': 0.5534993509077736, 'xgb_col': 0.6045454660808472, 'xgb_gamma': 2.4844627175702683, 'xgb_alpha': 7.3631169823305935, 'xgb_lambda': 0.0004304413401958504}. Best is trial 78 with value: 0.657256283774744.
# [I 2025-07-24 17:22:42,127] Trial 177 finished with value: 0.6467593910578866 and parameters: {'model': 'xgb', 'xgb_lr': 0.07619395097711196, 'xgb_est': 859, 'xgb_depth': 8, 'xgb_mc': 0.59662637119259, 'xgb_sub': 0.5479181867519928, 'xgb_col': 0.6207039629439706, 'xgb_gamma': 3.365872130811338, 'xgb_alpha': 0.001325904203562506, 'xgb_lambda': 0.0009186136669332261}. Best is trial 78 with value: 0.657256283774744.
# [I 2025-07-24 17:22:48,042] Trial 178 finished with value: 0.6536362171891035 and parameters: {'model': 'xgb', 'xgb_lr': 0.03757355675078813, 'xgb_est': 930, 'xgb_depth': 4, 'xgb_mc': 1.0371679461587153, 'xgb_sub': 0.5643776194608983, 'xgb_col': 0.5952697954345315, 'xgb_gamma': 2.579424112637321, 'xgb_alpha': 0.00023306495709196992, 'xgb_lambda': 1.3576360638209174e-06}. Best is trial 78 with value: 0.657256283774744.
# [I 2025-07-24 17:22:54,006] Trial 179 finished with value: 0.6543409871245071 and parameters: {'model': 'xgb', 'xgb_lr': 0.03792312529027784, 'xgb_est': 953, 'xgb_depth': 4, 'xgb_mc': 0.4737940817908354, 'xgb_sub': 0.5648650884764846, 'xgb_col': 0.5957833557012129, 'xgb_gamma': 2.709400269013078, 'xgb_alpha': 0.0006379590830620588, 'xgb_lambda': 0.0025521537121503328}. Best is trial 78 with value: 0.657256283774744.
# [I 2025-07-24 17:23:00,090] Trial 180 finished with value: 0.6495892513635507 and parameters: {'model': 'xgb', 'xgb_lr': 0.0386596617349259, 'xgb_est': 944, 'xgb_depth': 4, 'xgb_mc': 0.8613266378598904, 'xgb_sub': 0.5691923558185913, 'xgb_col': 0.5940810594329038, 'xgb_gamma': 2.5456864953263634, 'xgb_alpha': 0.00026106292221410955, 'xgb_lambda': 0.0028139136566510286}. Best is trial 78 with value: 0.657256283774744.
# [I 2025-07-24 17:23:05,909] Trial 181 finished with value: 0.6535482374355357 and parameters: {'model': 'xgb', 'xgb_lr': 0.04204009591748515, 'xgb_est': 927, 'xgb_depth': 3, 'xgb_mc': 0.41239477557513005, 'xgb_sub': 0.5602996746694361, 'xgb_col': 0.7123262406157471, 'xgb_gamma': 2.62191152097196, 'xgb_alpha': 0.000513663524553836, 'xgb_lambda': 0.0013655634963442142}. Best is trial 78 with value: 0.657256283774744.
# [I 2025-07-24 17:23:11,774] Trial 182 finished with value: 0.65869973165744 and parameters: {'model': 'xgb', 'xgb_lr': 0.041861619819958854, 'xgb_est': 943, 'xgb_depth': 3, 'xgb_mc': 0.5056820696137888, 'xgb_sub': 0.5584747753574701, 'xgb_col': 0.7260036546135277, 'xgb_gamma': 2.6265768358914037, 'xgb_alpha': 0.0009304154943237876, 'xgb_lambda': 0.0015743977220746758}. Best is trial 182 with value: 0.65869973165744.
# [I 2025-07-24 17:23:17,418] Trial 183 finished with value: 0.6506773655731821 and parameters: {'model': 'xgb', 'xgb_lr': 0.03734591333933808, 'xgb_est': 893, 'xgb_depth': 3, 'xgb_mc': 0.47819662133439544, 'xgb_sub': 0.5741296046262329, 'xgb_col': 0.6091792460508723, 'xgb_gamma': 2.822266652978155, 'xgb_alpha': 0.001827689725052078, 'xgb_lambda': 0.004465310911078266}. Best is trial 182 with value: 0.65869973165744.
# [I 2025-07-24 17:23:23,135] Trial 184 finished with value: 0.653788524692408 and parameters: {'model': 'xgb', 'xgb_lr': 0.049347368830263985, 'xgb_est': 943, 'xgb_depth': 4, 'xgb_mc': 0.6278421162058443, 'xgb_sub': 0.5604506679005008, 'xgb_col': 0.5827646763660443, 'xgb_gamma': 2.9985017887001235, 'xgb_alpha': 0.00012381796696359277, 'xgb_lambda': 0.0015165852053270713}. Best is trial 182 with value: 0.65869973165744.
# [I 2025-07-24 17:23:30,988] Trial 185 finished with value: 0.6531682798508988 and parameters: {'model': 'xgb', 'xgb_lr': 0.048014871395211274, 'xgb_est': 969, 'xgb_depth': 4, 'xgb_mc': 0.6226179182606962, 'xgb_sub': 0.5880973198622732, 'xgb_col': 0.7356202265418232, 'xgb_gamma': 2.204864285434488, 'xgb_alpha': 0.0001383988945112522, 'xgb_lambda': 0.009714250081989237}. Best is trial 182 with value: 0.65869973165744.
# [I 2025-07-24 17:23:38,433] Trial 186 finished with value: 0.6496164335907271 and parameters: {'model': 'xgb', 'xgb_lr': 0.05045390572372513, 'xgb_est': 955, 'xgb_depth': 5, 'xgb_mc': 0.48706394680712856, 'xgb_sub': 0.6040371492763609, 'xgb_col': 0.5809315476576772, 'xgb_gamma': 3.226572006753744, 'xgb_alpha': 0.000626865940292475, 'xgb_lambda': 0.0019516082717005443}. Best is trial 182 with value: 0.65869973165744.
# [I 2025-07-24 17:23:38,824] Trial 187 finished with value: 0.5416875633955329 and parameters: {'model': 'dt', 'dt_crit': 'entropy', 'dt_depth': 7, 'dt_split': 10, 'dt_leaf': 9}. Best is trial 182 with value: 0.65869973165744.
# [I 2025-07-24 17:23:45,969] Trial 188 finished with value: 0.6563777480739218 and parameters: {'model': 'xgb', 'xgb_lr': 0.059904649005431965, 'xgb_est': 892, 'xgb_depth': 4, 'xgb_mc': 0.6293345979021003, 'xgb_sub': 0.55427738036871, 'xgb_col': 0.5709516575018767, 'xgb_gamma': 2.9501308522003926, 'xgb_alpha': 0.000865052143502854, 'xgb_lambda': 0.000619157500481126}. Best is trial 182 with value: 0.65869973165744.
# [I 2025-07-24 17:23:50,871] Trial 189 finished with value: 0.6475320654103086 and parameters: {'model': 'xgb', 'xgb_lr': 0.060835039606558824, 'xgb_est': 783, 'xgb_depth': 4, 'xgb_mc': 0.6093875918832823, 'xgb_sub': 0.5540089624309553, 'xgb_col': 0.5720164099929694, 'xgb_gamma': 3.1161822615294614, 'xgb_alpha': 0.0024165471290105195, 'xgb_lambda': 0.000983911616657545}. Best is trial 182 with value: 0.65869973165744.
# [I 2025-07-24 17:23:56,468] Trial 190 finished with value: 0.6518714740804934 and parameters: {'model': 'xgb', 'xgb_lr': 0.05940806211143156, 'xgb_est': 928, 'xgb_depth': 3, 'xgb_mc': 0.5292606052799798, 'xgb_sub': 0.5792170528611215, 'xgb_col': 0.7688990226163657, 'xgb_gamma': 3.0178834621067496, 'xgb_alpha': 0.0010478392626965451, 'xgb_lambda': 0.0027134515855548247}. Best is trial 182 with value: 0.65869973165744.
# [I 2025-07-24 17:24:02,105] Trial 191 finished with value: 0.6486466493176268 and parameters: {'model': 'xgb', 'xgb_lr': 0.040534489566155206, 'xgb_est': 886, 'xgb_depth': 4, 'xgb_mc': 0.3730661080228371, 'xgb_sub': 0.5565925330999354, 'xgb_col': 0.5870216209101076, 'xgb_gamma': 2.886978621733987, 'xgb_alpha': 0.00360278647108169, 'xgb_lambda': 0.0005728852019487487}. Best is trial 182 with value: 0.65869973165744.
# [I 2025-07-24 17:24:07,822] Trial 192 finished with value: 0.650634626634964 and parameters: {'model': 'xgb', 'xgb_lr': 0.06549601578970542, 'xgb_est': 963, 'xgb_depth': 5, 'xgb_mc': 0.6627515332736982, 'xgb_sub': 0.5637027672642774, 'xgb_col': 0.5599465850929884, 'xgb_gamma': 2.7277639175251482, 'xgb_alpha': 0.00011729720524585337, 'xgb_lambda': 0.000704407661835212}. Best is trial 182 with value: 0.65869973165744.
# [I 2025-07-24 17:24:13,711] Trial 193 finished with value: 0.6521658147848575 and parameters: {'model': 'xgb', 'xgb_lr': 0.04183505992615968, 'xgb_est': 909, 'xgb_depth': 4, 'xgb_mc': 0.08299845412395256, 'xgb_sub': 0.5389097367769443, 'xgb_col': 0.5996034808864458, 'xgb_gamma': 2.3722865997314617, 'xgb_alpha': 0.0008378787005514603, 'xgb_lambda': 0.0014301255996283944}. Best is trial 182 with value: 0.65869973165744.
# [I 2025-07-24 17:25:01,150] Trial 194 finished with value: 0.6174957744430618 and parameters: {'model': 'rf', 'rf_estimators': 742, 'rf_depth': 13, 'rf_split': 16, 'rf_leaf': 5, 'rf_maxfeat': None, 'rf_bootstrap': True}. Best is trial 182 with value: 0.65869973165744.
# [I 2025-07-24 17:25:06,884] Trial 195 finished with value: 0.6483817824454652 and parameters: {'model': 'xgb', 'xgb_lr': 0.0559229384384928, 'xgb_est': 942, 'xgb_depth': 4, 'xgb_mc': 0.2450516587467548, 'xgb_sub': 0.5712014922374891, 'xgb_col': 0.5683818108923787, 'xgb_gamma': 2.9082321805657525, 'xgb_alpha': 0.0009388766674402609, 'xgb_lambda': 0.00030343254476507026}. Best is trial 182 with value: 0.65869973165744.
# [I 2025-07-24 17:25:12,351] Trial 196 finished with value: 0.6509426621091835 and parameters: {'model': 'xgb', 'xgb_lr': 0.03445041244864629, 'xgb_est': 820, 'xgb_depth': 3, 'xgb_mc': 0.8211635544536509, 'xgb_sub': 0.5909207355127887, 'xgb_col': 0.6179496233500097, 'xgb_gamma': 1.860697420596913, 'xgb_alpha': 4.366458907274818e-05, 'xgb_lambda': 4.9521100350676725e-05}. Best is trial 182 with value: 0.65869973165744.
# [I 2025-07-24 17:25:18,365] Trial 197 finished with value: 0.6519191096633655 and parameters: {'model': 'xgb', 'xgb_lr': 0.046883933763054296, 'xgb_est': 986, 'xgb_depth': 5, 'xgb_mc': 0.11153731455103419, 'xgb_sub': 0.5558372227421945, 'xgb_col': 0.581253284485163, 'xgb_gamma': 3.256601015472089, 'xgb_alpha': 0.0003416240497000378, 'xgb_lambda': 1.833983958627885e-05}. Best is trial 182 with value: 0.65869973165744.
# [I 2025-07-24 17:25:24,259] Trial 198 finished with value: 0.654640743964851 and parameters: {'model': 'xgb', 'xgb_lr': 0.03000182494327341, 'xgb_est': 916, 'xgb_depth': 5, 'xgb_mc': 1.49149806148079, 'xgb_sub': 0.5771005784810666, 'xgb_col': 0.5532530624643213, 'xgb_gamma': 3.139106486592397, 'xgb_alpha': 0.00042394940014337494, 'xgb_lambda': 3.2360439481003164e-06}. Best is trial 182 with value: 0.65869973165744.
# [I 2025-07-24 17:25:30,102] Trial 199 finished with value: 0.652552473466389 and parameters: {'model': 'xgb', 'xgb_lr': 0.02917763791668131, 'xgb_est': 908, 'xgb_depth': 5, 'xgb_mc': 1.3834826569077892, 'xgb_sub': 0.5720869900862351, 'xgb_col': 0.6047198982633387, 'xgb_gamma': 3.0786521740456827, 'xgb_alpha': 0.0004068671672768699, 'xgb_lambda': 3.2128953925321484e-06}. Best is trial 182 with value: 0.65869973165744.
# Best macro-F1: 0.65869973165744
# Best params : {'model': 'xgb', 'xgb_lr': 0.041861619819958854, 'xgb_est': 943, 'xgb_depth': 3, 'xgb_mc': 0.5056820696137888, 'xgb_sub': 0.5584747753574701, 'xgb_col': 0.7260036546135277, 'xgb_gamma': 2.6265768358914037, 'xgb_alpha': 0.0009304154943237876, 'xgb_lambda': 0.0015743977220746758}

# %%
best_trials = {}
for t in study.trials:                       # study è l'oggetto Optuna già ottimizzato
    mdl = t.params['model']
    if mdl not in best_trials or t.value > best_trials[mdl].value:
        best_trials[mdl] = t

print("Ho trovato:", list(best_trials.keys()))   # ['lgbm','xgb','rf','dt'] (in base ai tuoi risultati)
# Out:
# Ho trovato: ['lgbm', 'xgb', 'dt', 'rf']

# %%
best_trials
# Out:
# {'lgbm': FrozenTrial(number=42, state=1, values=[0.6492904390085987], datetime_start=datetime.datetime(2025, 7, 24, 17, 9, 45, 243990), datetime_complete=datetime.datetime(2025, 7, 24, 17, 9, 56, 963208), params={'model': 'lgbm', 'lgb_lr': 0.066954198416256, 'lgb_est': 250, 'lgb_leaves': 111, 'lgb_ff': 0.9409680053431105, 'lgb_bf': 0.5653057718207538, 'lgb_freq': 0, 'lgb_alpha': 0.8223034525325068, 'lgb_lambda': 1.4004064153182945}, user_attrs={}, system_attrs={}, intermediate_values={}, distributions={'model': CategoricalDistribution(choices=('lgbm', 'xgb', 'dt', 'rf')), 'lgb_lr': FloatDistribution(high=0.2, log=True, low=0.01, step=None), 'lgb_est': IntDistribution(high=1000, log=False, low=100, step=1), 'lgb_leaves': IntDistribution(high=255, log=False, low=31, step=1), 'lgb_ff': FloatDistribution(high=1.0, log=False, low=0.6, step=None), 'lgb_bf': FloatDistribution(high=1.0, log=False, low=0.5, step=None), 'lgb_freq': IntDistribution(high=5, log=False, low=0, step=1), 'lgb_alpha': FloatDistribution(high=10.0, log=True, low=1e-08, step=None), 'lgb_lambda': FloatDistribution(high=10.0, log=True, low=1e-08, step=None)}, trial_id=42, value=None),
#  'xgb': FrozenTrial(number=182, state=1, values=[0.65869973165744], datetime_start=datetime.datetime(2025, 7, 24, 17, 23, 5, 914613), datetime_complete=datetime.datetime(2025, 7, 24, 17, 23, 11, 772736), params={'model': 'xgb', 'xgb_lr': 0.041861619819958854, 'xgb_est': 943, 'xgb_depth': 3, 'xgb_mc': 0.5056820696137888, 'xgb_sub': 0.5584747753574701, 'xgb_col': 0.7260036546135277, 'xgb_gamma': 2.6265768358914037, 'xgb_alpha': 0.0009304154943237876, 'xgb_lambda': 0.0015743977220746758}, user_attrs={}, system_attrs={}, intermediate_values={}, distributions={'model': CategoricalDistribution(choices=('lgbm', 'xgb', 'dt', 'rf')), 'xgb_lr': FloatDistribution(high=0.2, log=True, low=0.01, step=None), 'xgb_est': IntDistribution(high=1000, log=False, low=100, step=1), 'xgb_depth': IntDistribution(high=12, log=False, low=3, step=1), 'xgb_mc': FloatDistribution(high=10.0, log=True, low=0.001, step=None), 'xgb_sub': FloatDistribution(high=1.0, log=False, low=0.5, step=None), 'xgb_col': FloatDistribution(high=1.0, log=False, low=0.5, step=None), 'xgb_gamma': FloatDistribution(high=5.0, log=False, low=0.0, step=None), 'xgb_alpha': FloatDistribution(high=10.0, log=True, low=1e-08, step=None), 'xgb_lambda': FloatDistribution(high=10.0, log=True, low=1e-08, step=None)}, trial_id=182, value=None),
#  'dt': FrozenTrial(number=8, state=1, values=[0.5482110185923309], datetime_start=datetime.datetime(2025, 7, 24, 16, 50, 31, 106882), datetime_complete=datetime.datetime(2025, 7, 24, 16, 50, 31, 344795), params={'model': 'dt', 'dt_crit': 'gini', 'dt_depth': 5, 'dt_split': 13, 'dt_leaf': 5}, user_attrs={}, system_attrs={}, intermediate_values={}, distributions={'model': CategoricalDistribution(choices=('lgbm', 'xgb', 'dt', 'rf')), 'dt_crit': CategoricalDistribution(choices=('gini', 'entropy')), 'dt_depth': IntDistribution(high=20, log=False, low=2, step=1), 'dt_split': IntDistribution(high=20, log=False, low=2, step=1), 'dt_leaf': IntDistribution(high=20, log=False, low=1, step=1)}, trial_id=8, value=None),
#  'rf': FrozenTrial(number=194, state=1, values=[0.6174957744430618], datetime_start=datetime.datetime(2025, 7, 24, 17, 24, 13, 711116), datetime_complete=datetime.datetime(2025, 7, 24, 17, 25, 1, 150904), params={'model': 'rf', 'rf_estimators': 742, 'rf_depth': 13, 'rf_split': 16, 'rf_leaf': 5, 'rf_maxfeat': None, 'rf_bootstrap': True}, user_attrs={}, system_attrs={}, intermediate_values={}, distributions={'model': CategoricalDistribution(choices=('lgbm', 'xgb', 'dt', 'rf')), 'rf_estimators': IntDistribution(high=1000, log=False, low=100, step=1), 'rf_depth': IntDistribution(high=30, log=False, low=5, step=1), 'rf_split': IntDistribution(high=20, log=False, low=2, step=1), 'rf_leaf': IntDistribution(high=20, log=False, low=1, step=1), 'rf_maxfeat': CategoricalDistribution(choices=('sqrt', 'log2', None)), 'rf_bootstrap': CategoricalDistribution(choices=(True, False))}, trial_id=194, value=None)}

# %%
def build_estimator(mname, params, n_classes):
    if mname == 'lgbm':
        return lgb.LGBMClassifier(
            objective='multiclass', num_class=n_classes, n_jobs=4, random_state=42,
            learning_rate=params['lgb_lr'],
            n_estimators=params['lgb_est'],
            num_leaves=params['lgb_leaves'],
            feature_fraction=params['lgb_ff'],
            bagging_fraction=params['lgb_bf'],
            bagging_freq=params['lgb_freq'],
            reg_alpha=params['lgb_alpha'],
            reg_lambda=params['lgb_lambda']
        )
    if mname == 'xgb':
        return XGBClassifier(
            objective='multi:softprob', num_class=n_classes, n_jobs=4, random_state=42,
            eval_metric='mlogloss',
            learning_rate=params['xgb_lr'],
            n_estimators=params['xgb_est'],
            max_depth=params['xgb_depth'],
            min_child_weight=params['xgb_mc'],
            subsample=params['xgb_sub'],
            colsample_bytree=params['xgb_col'],
            gamma=params['xgb_gamma'],
            reg_alpha=params['xgb_alpha'],
            reg_lambda=params['xgb_lambda'],
            tree_method='hist'
        )
    if mname == 'rf':
        return RandomForestClassifier(
            random_state=42, n_jobs=-1,
            n_estimators=params['rf_estimators'],
            max_depth=params['rf_depth'],
            min_samples_split=params['rf_split'],
            min_samples_leaf=params['rf_leaf'],
            max_features=params['rf_maxfeat'],
            bootstrap=params['rf_bootstrap']
        )
    if mname == 'dt':
        return DecisionTreeClassifier(
            random_state=42,
            criterion=params['dt_crit'],
            max_depth=params['dt_depth'],
            min_samples_split=params['dt_split'],
            min_samples_leaf=params['dt_leaf']
        )

# %%
# ---------- 3. definisci lo scoring ----------
scoring = {
    'accuracy':  make_scorer(accuracy_score),
    'precision': make_scorer(precision_score, average='macro', zero_division=0),
    'recall':    make_scorer(recall_score,    average='macro', zero_division=0),
    'f1':        make_scorer(f1_score,        average='macro', zero_division=0)
}

cv = StratifiedKFold(n_splits=10, shuffle=True, random_state=42)

# ---------- 4. loop e cross-validate ----------
cv_results = {}  
records = []
for mdl_name, trial in best_trials.items():
    est = build_estimator(mdl_name, trial.params, n_classes=len(le.classes_))
    cv_res = cross_validate(est, X_train, y_train_enc, cv=cv,
                            scoring=scoring, n_jobs=-1, return_train_score=False)
    
    cv_results[mdl_name.upper()] = cv_res   # <── salviamo!

    records.append({
        'Model': mdl_name.upper(),
        'Accuracy mean':  cv_res['test_accuracy'].mean(),
        'Accuracy SD':    cv_res['test_accuracy'].std(),
        'Precision mean': cv_res['test_precision'].mean(),
        'Precision SD':   cv_res['test_precision'].std(),
        'Recall mean':    cv_res['test_recall'].mean(),
        'Recall SD':      cv_res['test_recall'].std(),
        'F1 mean':        cv_res['test_f1'].mean(),
        'F1 SD':          cv_res['test_f1'].std()
    })

results_df = pd.DataFrame(records).set_index('Model').round(3)
display(results_df)   # in Jupyter / VS Code mostra la tabella
# Out:
#        Accuracy mean  Accuracy SD  Precision mean  Precision SD  Recall mean  \
# Model
# LGBM           0.669        0.040           0.656         0.041        0.651
# XGB            0.678        0.028           0.664         0.029        0.659
# DT             0.573        0.019           0.554         0.028        0.552
# RF             0.647        0.022           0.632         0.023        0.623
#
#        Recall SD  F1 mean  F1 SD
# Model
# LGBM       0.042    0.649  0.042
# XGB        0.028    0.659  0.028
# DT         0.023    0.548  0.027
# RF         0.022    0.617  0.024

# %%
# ---------- 1. prepara il contenitore risultati ----------
test_records = []

# ---------- 2. cicla sui modelli "vincitori" ----------
for mdl_name, trial in best_trials.items():
    
    # 2a. ricostruisci il modello con i parametri ottimali
    est = build_estimator(
        mdl_name,
        trial.params,
        n_classes=len(le.classes_)        # stesso LabelEncoder di prima
    )
    
    # 2b. allena su TUTTO il train (2017-2018)
    est.fit(X_train, y_train_enc)
    
    # 2c. predici sul test (2019)
    y_pred = est.predict(X_test)
    
    # 2d. calcola le metriche
    acc  = accuracy_score(y_test_enc, y_pred)
    prec = precision_score(y_test_enc, y_pred, average='macro', zero_division=0)
    rec  = recall_score(y_test_enc,  y_pred, average='macro', zero_division=0)
    f1   = f1_score(y_test_enc,      y_pred, average='macro', zero_division=0)
    
    test_records.append({
        'Model': mdl_name.upper(),
        'Accuracy':  acc,
        'Precision': prec,
        'Recall':    rec,
        'F1':        f1
    })
    
    # 2e. (opz.) stampa un report dettagliato
    print(f"\n=== {mdl_name.upper()} — Test 2019 ===")
    print(classification_report(
        y_test_enc, y_pred,
        target_names=le.classes_,
        zero_division=0
    ))
    # (opz.) cm = confusion_matrix(y_test_enc, y_pred)

# ---------- 3. tabella riassuntiva ----------
test_df = (
    pd.DataFrame(test_records)
      .set_index('Model')
      .round(3)
      .sort_values('F1', ascending=False)
)

display(test_df)
# Out:
# [LightGBM] [Warning] feature_fraction is set=0.9409680053431105, colsample_bytree=1.0 will be ignored. Current value: feature_fraction=0.9409680053431105
# [LightGBM] [Warning] bagging_fraction is set=0.5653057718207538, subsample=1.0 will be ignored. Current value: bagging_fraction=0.5653057718207538
# [LightGBM] [Warning] bagging_freq is set=0, subsample_freq=0 will be ignored. Current value: bagging_freq=0
# [LightGBM] [Warning] feature_fraction is set=0.9409680053431105, colsample_bytree=1.0 will be ignored. Current value: feature_fraction=0.9409680053431105
# [LightGBM] [Warning] bagging_fraction is set=0.5653057718207538, subsample=1.0 will be ignored. Current value: bagging_fraction=0.5653057718207538
# [LightGBM] [Warning] bagging_freq is set=0, subsample_freq=0 will be ignored. Current value: bagging_freq=0
# [LightGBM] [Info] Auto-choosing row-wise multi-threading, the overhead of testing was 0.002115 seconds.
# You can set `force_row_wise=true` to remove the overhead.
# And if memory is not enough, you can set `force_col_wise=true`.
# [LightGBM] [Info] Total Bins 779
# [LightGBM] [Info] Number of data points in the train set: 2164, number of used features: 184
# [LightGBM] [Info] Start training from score -1.096304
# [LightGBM] [Info] Start training from score -1.316686
# [LightGBM] [Info] Start training from score -0.921619
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] feature_fraction is set=0.9409680053431105, colsample_bytree=1.0 will be ignored. Current value: feature_fraction=0.9409680053431105
# [LightGBM] [Warning] bagging_fraction is set=0.5653057718207538, subsample=1.0 will be ignored. Current value: bagging_fraction=0.5653057718207538
# [LightGBM] [Warning] bagging_freq is set=0, subsample_freq=0 will be ignored. Current value: bagging_freq=0
#
# === LGBM — Test 2019 ===
#               precision    recall  f1-score   support
#
#       Dx/CDx       0.71      0.70      0.71       379
#          M5S       0.54      0.37      0.44       289
#       Sx/CSx       0.72      0.86      0.78       487
#
#     accuracy                           0.68      1155
#    macro avg       0.66      0.64      0.64      1155
# weighted avg       0.67      0.68      0.67      1155
#
#
# === XGB — Test 2019 ===
#               precision    recall  f1-score   support
#
#       Dx/CDx       0.73      0.71      0.72       379
#          M5S       0.54      0.37      0.44       289
#       Sx/CSx       0.71      0.86      0.78       487
#
#     accuracy                           0.69      1155
#    macro avg       0.66      0.65      0.65      1155
# weighted avg       0.68      0.69      0.68      1155
#
#
# === DT — Test 2019 ===
#               precision    recall  f1-score   support
#
#       Dx/CDx       0.65      0.74      0.69       379
#          M5S       0.47      0.33      0.39       289
#       Sx/CSx       0.75      0.80      0.77       487
#
#     accuracy                           0.66      1155
#    macro avg       0.62      0.62      0.62      1155
# weighted avg       0.65      0.66      0.65      1155
#
#
# === RF — Test 2019 ===
#               precision    recall  f1-score   support
#
#       Dx/CDx       0.68      0.79      0.73       379
#          M5S       0.57      0.28      0.38       289
#       Sx/CSx       0.74      0.86      0.79       487
#
#     accuracy                           0.69      1155
#    macro avg       0.66      0.65      0.63      1155
# weighted avg       0.68      0.69      0.67      1155
#        Accuracy  Precision  Recall     F1
# Model
# XGB       0.689      0.661   0.647  0.647
# LGBM      0.685      0.655   0.643  0.642
# RF        0.694      0.661   0.645  0.634
# DT        0.663      0.623   0.624  0.619

# %%
# ---------------------------------------------------------
# 0.  Prerequisiti (già esistenti nel tuo notebook)
#     - best_trials        : dict con i parametri ottimali per ogni modello
#     - build_estimator()  : funzione che restituisce il modello dato il nome
#     - X_train, y_train_enc, X_test   : dati già pronti
# ---------------------------------------------------------

# Dizionario dove salveremo le predizioni sul test-set 2019
models_pred = {}

for mdl_name, trial in best_trials.items():
    # 1. ricostruisci il modello con i suoi parametri
    est = build_estimator(
        mdl_name, 
        trial.params, 
        n_classes=len(le.classes_)      # stesso LabelEncoder usato prima
    )

    # 2. allena sul 100 % del train (2017–2018)
    est.fit(X_train, y_train_enc)
    
    # 3. predici le etichette del test (2019) e salva
    models_pred[mdl_name.upper()] = est.predict(X_test)

# Ora hai:
y_pred_RF   = models_pred['RF']
y_pred_LGBM = models_pred['LGBM']
y_pred_XGB  = models_pred['XGB']
y_pred_DT   = models_pred['DT']

print({k: v.shape for k, v in models_pred.items()})
# ➜ {'RF': (1155,), 'LGBM': (1155,), 'XGB': (1155,), 'DT': (1155,)}
# Out:
# [LightGBM] [Warning] feature_fraction is set=0.9409680053431105, colsample_bytree=1.0 will be ignored. Current value: feature_fraction=0.9409680053431105
# [LightGBM] [Warning] bagging_fraction is set=0.5653057718207538, subsample=1.0 will be ignored. Current value: bagging_fraction=0.5653057718207538
# [LightGBM] [Warning] bagging_freq is set=0, subsample_freq=0 will be ignored. Current value: bagging_freq=0
# [LightGBM] [Warning] feature_fraction is set=0.9409680053431105, colsample_bytree=1.0 will be ignored. Current value: feature_fraction=0.9409680053431105
# [LightGBM] [Warning] bagging_fraction is set=0.5653057718207538, subsample=1.0 will be ignored. Current value: bagging_fraction=0.5653057718207538
# [LightGBM] [Warning] bagging_freq is set=0, subsample_freq=0 will be ignored. Current value: bagging_freq=0
# [LightGBM] [Info] Auto-choosing row-wise multi-threading, the overhead of testing was 0.001918 seconds.
# You can set `force_row_wise=true` to remove the overhead.
# And if memory is not enough, you can set `force_col_wise=true`.
# [LightGBM] [Info] Total Bins 779
# [LightGBM] [Info] Number of data points in the train set: 2164, number of used features: 184
# [LightGBM] [Info] Start training from score -1.096304
# [LightGBM] [Info] Start training from score -1.316686
# [LightGBM] [Info] Start training from score -0.921619
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] feature_fraction is set=0.9409680053431105, colsample_bytree=1.0 will be ignored. Current value: feature_fraction=0.9409680053431105
# [LightGBM] [Warning] bagging_fraction is set=0.5653057718207538, subsample=1.0 will be ignored. Current value: bagging_fraction=0.5653057718207538
# [LightGBM] [Warning] bagging_freq is set=0, subsample_freq=0 will be ignored. Current value: bagging_freq=0
# {'LGBM': (1155,), 'XGB': (1155,), 'DT': (1155,), 'RF': (1155,)}

# %%
from scipy.stats import ttest_rel, wilcoxon

# %%
cv_res_LGBM = cv_results['LGBM']           # dict con tutte le metriche per fold
cv_res_RF = cv_results['RF']  
cv_res_XGB = cv_results['XGB']  
cv_res_DT = cv_results['DT']

# %%
import itertools, numpy as np, pandas as pd
from scipy.stats import ttest_rel, wilcoxon
from sklearn.metrics import (
    accuracy_score, precision_score, recall_score, f1_score
)

# ──────────────────────────────────────────────────────────────
# 1.  F1 sulle 10 fold  →  t-test & Wilcoxon (tutte le coppie)
# ──────────────────────────────────────────────────────────────
cv_f1 = {
    'RF'  : cv_res_RF['test_f1'],
    'LGBM': cv_res_LGBM['test_f1'],
    'XGB' : cv_res_XGB['test_f1'],
    'DT'  : cv_res_DT['test_f1'],
}

rows_cv = []
for m1, m2 in itertools.combinations(cv_f1, 2):
    t_stat, p_t  = ttest_rel(cv_f1[m1], cv_f1[m2])
    w_stat, p_w  = wilcoxon(cv_f1[m1], cv_f1[m2])
    rows_cv.append({
        'Model 1': m1, 'Model 2': m2,
        'ΔF1 (mean)': np.mean(cv_f1[m1] - cv_f1[m2]),
        't-test p':   p_t,
        'Wilcoxon p': p_w,
    })

cv_tests_df = (pd.DataFrame(rows_cv)
               .sort_values('Wilcoxon p')
               .round(4))
display(cv_tests_df)

# ──────────────────────────────────────────────────────────────
# 2.  Bootstrap accoppiato 10 000× sul test 2019
#     → CI e p-value ΔF1   +   CI per tutte le metriche
# ──────────────────────────────────────────────────────────────
models_pred = {
    'RF'  : y_pred_RF,
    'LGBM': y_pred_LGBM,
    'XGB' : y_pred_XGB,
    'DT'  : y_pred_DT,
}

def metrics(y_true, y_hat):
    return dict(
        Accuracy  = accuracy_score(y_true, y_hat),
        Precision = precision_score(y_true, y_hat, average='macro', zero_division=0),
        Recall    = recall_score(   y_true, y_hat, average='macro', zero_division=0),
        F1        = f1_score(       y_true, y_hat, average='macro', zero_division=0)
    )

B   = 10_000
rng = np.random.default_rng(42)
n   = len(y_test_enc)

# container bootstrap
boot = {m: {k: [] for k in ['Accuracy','Precision','Recall','F1']}
        for m in models_pred}

for _ in range(B):
    idx = rng.integers(0, n, n)        # campione con reinserimento
    y_bs = y_test_enc[idx]
    for m, y_hat in models_pred.items():
        mtr = metrics(y_bs, y_hat[idx])
        for k, v in mtr.items():
            boot[m][k].append(v)

# ── tabella per modello: media + CI95
rows_summary = []
for m, d in boot.items():
    row = {'Model': m}
    for k in d:
        ci_low, ci_high = np.percentile(d[k], [2.5, 97.5])
        row[f'{k} mean'] = np.mean(d[k])
        row[f'{k} 95% CI'] = f"[{ci_low:.3f}, {ci_high:.3f}]"
    rows_summary.append(row)

summary_df = (pd.DataFrame(rows_summary)
              .set_index('Model')
              .round(3)
              .sort_values('F1 mean', ascending=False))
display(summary_df)

# ── ΔF1 paired-bootstrap per ogni coppia (come prima)
rows_bs = []
for m1, m2 in itertools.combinations(models_pred, 2):
    diff = np.array(boot[m1]['F1']) - np.array(boot[m2]['F1'])
    ci   = np.percentile(diff, [2.5, 97.5])
    p    = 2 * min((diff <= 0).mean(), (diff >= 0).mean())
    rows_bs.append({
        'Model 1': m1, 'Model 2': m2,
        'ΔF1 orig': metrics(y_test_enc, models_pred[m1])['F1']
                    - metrics(y_test_enc, models_pred[m2])['F1'],
        'ΔF1 95% CI': f"[{ci[0]:.3f}, {ci[1]:.3f}]",
        'Bootstrap p': p,
    })

bs_tests_df = (pd.DataFrame(rows_bs)
               .sort_values('Bootstrap p')
               .round(4))
display(bs_tests_df)
# Out:
#   Model 1 Model 2  ΔF1 (mean)  t-test p  Wilcoxon p
# 1      RF     XGB     -0.0412    0.0008      0.0020
# 2      RF      DT      0.0693    0.0001      0.0020
# 4    LGBM      DT      0.1011    0.0000      0.0020
# 5     XGB      DT      0.1105    0.0000      0.0020
# 0      RF    LGBM     -0.0318    0.0083      0.0137
# 3    LGBM     XGB     -0.0094    0.4011      0.6953
#        Accuracy mean Accuracy 95% CI  Precision mean Precision 95% CI  \
# Model
# XGB            0.689  [0.661, 0.715]           0.661   [0.630, 0.691]
# LGBM           0.685  [0.658, 0.711]           0.656   [0.625, 0.685]
# RF             0.693  [0.667, 0.719]           0.661   [0.628, 0.693]
# DT             0.663  [0.635, 0.690]           0.623   [0.592, 0.653]
#
#        Recall mean   Recall 95% CI  F1 mean       F1 95% CI
# Model
# XGB          0.647  [0.621, 0.673]    0.646  [0.617, 0.674]
# LGBM         0.643  [0.617, 0.669]    0.641  [0.613, 0.669]
# RF           0.645  [0.621, 0.670]    0.634  [0.606, 0.663]
# DT           0.624  [0.597, 0.650]    0.618  [0.590, 0.646]
#   Model 1 Model 2  ΔF1 orig       ΔF1 95% CI  Bootstrap p
# 5     XGB      DT    0.0279  [-0.003, 0.060]       0.0788
# 4    LGBM      DT    0.0230  [-0.009, 0.055]       0.1458
# 2      RF      DT    0.0158  [-0.010, 0.043]       0.2428
# 1      RF     XGB   -0.0121  [-0.037, 0.012]       0.3268
# 0      RF    LGBM   -0.0072  [-0.033, 0.019]       0.5828
# 3    LGBM     XGB   -0.0049  [-0.024, 0.014]       0.6464

# %%
df.shape
# Out:
# (3117, 121)
